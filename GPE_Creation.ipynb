# %% [markdown]
# import required packages and setup environment

# %%
import arcpy, os, re
from arcpy.sa import *
import pandas as pd
import numpy as np
import itertools as it
from IPython.display import clear_output

wd = os.getcwd()
arcpy.env.workspace = os.path.join(wd, "DataExploration.gdb")
scratch = os.path.join(wd, "scratch")
outputs = os.path.join(wd, "outputs")

arcpy.env.outputCoordinateSystem = arcpy.SpatialReference("NAD 1983 BC Environment Albers")
arcpy.env.overwriteOutput = True
arcpy.env.snapRaster = r"H:\Muise\forestMask\ForMask_UTM-7S-11S_1984.tif"
arcpy.env.cellSize = 30
arcpy.CheckOutExtension("spatial")
# Out:
# 'CheckedOut'

# %% [markdown]
# generate masked singlepart BEC zones to create GPE with

# %%
BEC = "Terr_BEC_Subzones"
mask = "Terr_ParksConsComplexes"

eraseOutput = "Terr_BEC_Erase"
mtsOutput = "Terr_BEC_Subzones_Multipart"

# %% [markdown]
# Testing subzone buffer

# %%
#erasedBEC = arcpy.Erase_analysis(BEC, mask, eraseOutput)
#arcpy.MultipartToSinglepart_management(erasedBEC, mtsOutput)

# %% [markdown]
# create two features classes: one for the non-complex protected areas, and one for the dissolved complexes

# %%
parkLayer = "Terr_ParksConsComplexes"

selection = 'Complex IS NOT NULL'

selected = arcpy.SelectLayerByAttribute_management(parkLayer, "NEW_SELECTION", selection)
complexes = arcpy.CopyFeatures_management(selected, os.path.join(scratch, "onlyComplexes.shp"))

dissolveComplexes = arcpy.Dissolve_management(complexes, "onlyComplexes",
                          "Complex", "", "MULTI_PART", 
                          "DISSOLVE_LINES")

arcpy.Delete_management(complexes)

selection2 = 'Complex IS NULL'
selected2 = arcpy.SelectLayerByAttribute_management(parkLayer, "NEW_SELECTION", selection2)
parks = arcpy.CopyFeatures_management(selected2, "onlyParks")
print("done")
# Out:
# done

# %%
parkLayer = "Terr_ParksConsComplexes"

selection = 'Complex IS NOT NULL'

#select_analysis should be faster than select then copy
complexes = arcpy.Select_analysis(parkLayer, os.path.join(scratch, "onlyComplexes.shp"), selection)

#selected = arcpy.SelectLayerByAttribute_management(parkLayer, "NEW_SELECTION", selection)
#complexes = arcpy.CopyFeatures_management(selected, os.path.join(scratch, "onlyComplexes.shp"))

dissolveComplexes = arcpy.Dissolve_management(complexes, "onlyComplexes",
                          "Complex", "", "MULTI_PART", 
                          "DISSOLVE_LINES")

arcpy.Delete_management(complexes)

selection2 = 'Complex IS NULL'

#select_analysis should be faster than select then copy
parks = arcpy.Select_analysis(parkLayer, os.path.join(scratch, "onlyParks"), selection2)

#selected2 = arcpy.SelectLayerByAttribute_management(parkLayer, "NEW_SELECTION", selection2)
#parks = arcpy.CopyFeatures_management(selected2, "onlyParks")
print("done")
# Out:
# done

# %%
regex = re.compile('[^a-zA-Z]')

with arcpy.da.UpdateCursor(parks, "PROTECTED_LANDS_NAME") as cursor:
    #removes all non-alphabetic characters for each polygon in the PROTECTED_LANDS_NAME field
    for row in cursor:
        row[0] = regex.sub('', row[0].title())

        # Update the cursor with the updated list
        cursor.updateRow(row)

# %% [markdown]
# generates the BEC GPE for a park, the select by attribute needs to be changed to updateCursor

# %%
def becGpeCreation(parkLayer, park, field, outList):
    #makes it simpler to do a select by attribute
    field = arcpy.AddFieldDelimiters(parkLayer, field)
    selection = "{field} = '{val}'".format(field=field, val=park)

    #removes all non alphabetic characters from the park name
    regex = re.compile('[^a-zA-Z]')
    gdbName = regex.sub('', park)

    #creates a folder and saves a file name
    #if you fuck up again and delete everything, change outputs in this line to gdbLocation and uncomment it
    #in the initialization cell
    newGdb = os.path.join(outputs, gdbName)
    if not os.path.isdir(newGdb):
        os.makedirs(os.path.join(newGdb))
    parkSaveName = os.path.join(str(newGdb), gdbName + ".shp")

    outList.append(parkSaveName)

    #selected parameterized park, saves it to the new geodatabase
    #select_analysis faster than select layer and copy features
    parkFeature = arcpy.Select_analysis(parkLayer, parkSaveName, selection)
    
    
    #selected = arcpy.SelectLayerByAttribute_management(parkLayer, "NEW_SELECTION", selection)
    #parkFeature = arcpy.CopyFeatures_management(selected, parkSaveName)

    #generates the GPE, saves it to the new geodatabase
    selectBEC = arcpy.SelectLayerByLocation_management(mtsOutput, 'intersect', parkFeature)
    becSaveName = os.path.join(str(newGdb), gdbName + "_BEC.shp")
    arcpy.CopyFeatures_management(selectBEC, becSaveName)
    
    becList.append(becSaveName)

# %%
def largest_contiguous(shapefile, save_location):

    
    print("converting to singlepart")
    singlepart_save = r"scratch\gpeSinglepart.shp" 

    singlePart = arcpy.MultipartToSinglepart_management(shapefile, singlepart_save) #make singlepart

    arr = arcpy.da.TableToNumPyArray(singlePart, 'SHAPE@AREA') #determine number of parts
    
    if len(arr) > 1: 
        #if there are more than 1 part, select only those that are larger than 40% of the largest part
        print("multiple polygons, adding field")
        field_names = [f.name for f in arcpy.ListFields(shapefile)]
        
        if "Shape_Area" not in field_names:
            arcpy.AddField_management(singlePart, "Shape_Area", "FLOAT")
            
        print("calculating geometry")
        arcpy.CalculateGeometryAttributes_management(singlePart, 
                                                 [["Shape_Area", "AREA"]], 
                                                 area_unit = "SQUARE_METERS")
        
        arr = arcpy.da.TableToNumPyArray(singlePart, 'Shape_Area')
        
        max_value = np.nanmax(arr.astype('float'))  
        

        where_clause = """"{}" {} {}""".format("Shape_Area", ">", str(int(max_value * .40)))
        print(where_clause)
        
        print("selecting and saving")
        arcpy.Select_analysis(singlePart, save_location, where_clause = where_clause)
    else:
        print("single polygon, saving")
        arcpy.CopyFeatures_management(singlePart, save_location)

# %%
def bufferProp(inShape, proportion = 1, sensitivity = 0.05, adjustment_rate = 0.05):
    
    print("math and initialization")

    arr = arcpy.da.TableToNumPyArray(inShape, 'SHAPE@AREA') #convert column to an array so i can pull the number
    geomArea = np.nanmax(arr.astype('float')) #total area
    r1 = math.sqrt(geomArea / math.pi) #radius of circle with total area
    r2 = math.sqrt(geomArea * 2 / math.pi) #radius of circle with double area
    buffer_length = r2 - r1 #difference of circle radius(to be buffered by)

    bec_location = inShape[:-4] + "_BEC" + inShape[-4:] #location of the BEC zones connected: for clipping by
    save_location = inShape[:-4] + "_GPE" + inShape[-4:] #final save location for when it works
    

    lowerBound = proportion - sensitivity #acceptable lower bound of the ratio of buffered area to park area
    upperBound = proportion + sensitivity #acceptable upper bound of the ratio of buffered area to park area

    ratio = None
    print("buffering")
    while (ratio is None or ratio < lowerBound or ratio > upperBound): #if ratio is not in bounds
        print(".", end = "") #sort of a progress bar
        if ratio == None: #start off with no ratio because the buffer doesnt exist yet
            ratio = ratio
            
        elif ratio > proportion:
            buffer_length *= (1 - adjustment_rate) #if ratio too small, decrease by adjustment rate

        elif ratio < proportion:
            buffer_length *= (1 + adjustment_rate) #if ratio too small, increase by adjustment rate
        
        #buffer by the buffer length and save to scratch folder
        buffered = arcpy.Buffer_analysis(inShape, os.path.join(scratch, "interBuffer.shp"), buffer_length)

        #if a ratio exists (has been buffered), then clip it to the nearby BEC zones
        if ratio != None:
            
            buffered = arcpy.Clip_analysis(buffered, bec_location, r"scratch\BufferClip")

        buff_arr = arcpy.da.TableToNumPyArray(buffered, 'SHAPE@AREA') #convert column to an array so i can pull the number
        if len(buff_arr) == 0 :
            break
        buffered_geomArea = np.nanmax(buff_arr.astype('float')) #total area of buffered shapefile

        previous_ratio = ratio


        ratio = buffered_geomArea / geomArea #calculate the ratio

        if previous_ratio is not None and (round(previous_ratio, 6) == round(ratio, 6)):
            break #if the ratio is the same between iterations, break the function since it is an island

        if lowerBound < ratio < upperBound: 
            #if the ratio is within bounds, run largest contiguous function

            print("largest contiguous")
            
            largest_contiguous(buffered, save_location) #get the largest contiguous features from the GPE

            return inShape, save_location

# %% [markdown]
# code to generate unique values in selected field: a workaround instead of using updateCursor for my specific use case

# %%
def unique_values(table , field):
    with arcpy.da.SearchCursor(table, [field]) as cursor:
        return ({row[0] for row in cursor})

# %%
def subzones(ppa, gpe, overwrite = True, min_size = 1000):
    
    print("init")

    expression = "Shape_Area < " + str(int(min_size))

    #generates save names for intersect
    folder = ppa.rsplit("\\", 1)[0]
    ppaName = ppa.rsplit('\\', 1)[-1].split(".")[0]
    gpeName = gpe.rsplit('\\', 1)[-1].split(".")[0]
    ppaSave = os.path.join(folder, ppaName + "_Subzones.shp")
    gpeSave = os.path.join(folder, gpeName + "_Subzones.shp")
    
    paceSaveSub = os.path.join(folder, ppaName + "_PACE_Subzones.shp")
    
    if overwrite is True or not os.path.exists(paceSaveSub):
        print("generating subzones")

        arcpy.CalculateField_management(ppa, "ppa_gpe", "'PPA'", "PYTHON3", field_type = "TEXT")
        arcpy.CalculateField_management(gpe, "ppa_gpe", "'GPE'", "PYTHON3", field_type = "TEXT")
        
        print("generating merged, unsubzoned")
        paceSave = os.path.join(folder, ppaName + "_PACE.shp")
        pace = arcpy.Merge_management([ppa, gpe], paceSave)
        
        print("intersecting for subzoned ppa")
        intersectedPpa = arcpy.Intersect_analysis([ppa, "Terr_BEC_Subzones"], r"scratch\intersectedPpa.shp")

        print("making singlepart")
        singlePart = arcpy.MultipartToSinglepart_management(intersectedPpa,
                                       r"scratch\ppaSinglepart.shp")
        
        #pull numbers, check if any below 1000
        ppa_arr = arcpy.da.TableToNumPyArray(singlePart, 'SHAPE@AREA')
        
        print(str(sum([i[0] < min_size for i in ppa_arr])), "slivers in PPA") #determines number of slivers

        if sum([i[0] < min_size for i in ppa_arr]) > 0:

            print("calculating geometry")
            arcpy.CalculateGeometryAttributes_management(singlePart, 
                                                         [["Shape_Area", "AREA"]], 
                                                         area_unit = "SQUARE_METERS")

            print("select for slivers")
            selection = arcpy.SelectLayerByAttribute_management(singlePart, 
                                                    "NEW_SELECTION", 
                                                    expression)        
            print("eliminate slivers")
            intersectedPpa = arcpy.Eliminate_management(selection, r"scratch/ppaEliminated")
        
        
        
        
        print("intersecting for subzoned gpe")
        intersectedGpe = arcpy.Intersect_analysis([gpe, "Terr_BEC_Subzones"], r"scratch\intersectedGpe.shp")

        print("making singlepart")
        singlePart = arcpy.MultipartToSinglepart_management(intersectedGpe,
                                       r"scratch\gpeSinglepart.shp")
        
        gpe_arr = arcpy.da.TableToNumPyArray(singlePart, 'SHAPE@AREA')
        
        print(str(sum([i[0] < min_size for i in gpe_arr])), "slivers in GPE") #determines number of slivers
        
        if sum([i[0] < min_size for i in gpe_arr]) > 0:
        
            print("calculating geometry")
            arcpy.CalculateGeometryAttributes_management(singlePart, 
                                                         [["Shape_Area", "AREA"]], 
                                                         area_unit = "SQUARE_METERS")

            print("select for slivers")
            selection = arcpy.SelectLayerByAttribute_management(singlePart, 
                                                    "NEW_SELECTION", 
                                                    expression)        
            print("eliminate slivers")
            intersectedGpe = arcpy.Eliminate_management(selection, r"scratch/gpeEliminated")
        
        print("merge eliminated shapefiles")
        pace = arcpy.Merge_management([intersectedPpa, intersectedGpe], paceSaveSub)
        
        print("add myFID field for data aggregation")
        arcpy.CalculateField_management(paceSaveSub, "myFID", "!FID!", "PYTHON3", field_type = "SHORT")

    return(paceSaveSub)

# %%
parkNames = unique_values(parks, "PROTECTED_LANDS_NAME")
complexNames = unique_values(dissolveComplexes, "Complex")
#parkNames = ("JoffreLakesPark", "MountSeymourPark", "StuartRiverParkLowerSite")
#complexNames = ("Gar", "Spats", "Strath")

# %%
#initialize lists to merge at end
parkList = []
becList = []

#becGpeCreation(parks, "EkwanLakeProtectedArea", "PROTECTED_LANDS_NAME")
num_files = len(parkNames)
num_done = 0
for park in parkNames:
    
    clear_output(True)
    num_done += 1
    print(str(num_done), "/", str(num_files))
    print(park)
    
    becGpeCreation(parks, park, "PROTECTED_LANDS_NAME", parkList)
    
print("done iteration, now merging")
# Out:
# done iteration, now merging
# done merging, running GPE buffer
#
# first attempt: no adjustment
# None
# 2.5754162072830487
# 1.4361960323791554
# 1.3634911063172632
# 1.2945516318019825
# 1.2291336969938422
# 1.1669145554451352
# 1.107664132420982
# 1.0514241077126847
# final ratio: 0.9980228469213434
# number of iterations: 9
# first attempt: no adjustment
# None
# 2.1989005219031577
# 1.1308643636810578
# 1.0669846475876439
# final ratio: 1.0070168494594796
# number of iterations: 4
# first attempt: no adjustment
# None
# 3.776740411413477
# 2.166053385516996
# 2.0776107459915223
# 1.9909292266467764
# 1.9066093827563475
# 1.824545317901134
# 1.7440431601128688
# 1.6668777327656399
# 1.5933295571774548
# 1.5226533280335912
# 1.4557262063398428
# 1.391970305441338
# 1.3310941233709428
# 1.272650891025987
# 1.2166637963633078
# 1.1630715784664454
# 1.1111566054105346
# 1.0608450020849898
# final ratio: 1.0126761199474636
# number of iterations: 19
# first attempt: no adjustment
# None
# 4.4076332463435355
# 1.5258014635382413
# 1.4472960565639235
# 1.3730906920355759
# 1.3029098122758047
# 1.2364902578253616
# 1.1735800605997984
# 1.1139269329196837
# 1.0572508850041047
# final ratio: 1.0033688051775582
# number of iterations: 10
# first attempt: no adjustment
# None
# 2.8459127962310005
# 1.7513504869603747
# 1.6621368068287414
# 1.577915154892279
# 1.4983566307324958
# 1.423173469211028
# 1.3521170275461554
# 1.2849283699389389
# 1.2214015911091898
# 1.161332626734092
# 1.1045138106299495
# 1.0507544701305387
# final ratio: 0.9998751927681584
# number of iterations: 13
# first attempt: no adjustment
# None
# 2.616511478522679
# 1.2772437199484288
# 1.2075066464293762
# 1.1420426213967394
# 1.0805101921180853
# final ratio: 1.0225766574771247
# number of iterations: 6
# first attempt: no adjustment
# None
# 2.9014834756396692
# 0.8360595448036542
# 0.8887012418881258
# 0.944916338350924
# final ratio: 1.0044798035429345
# number of iterations: 5
# first attempt: no adjustment
# None
# 2.2893062395583543
# 1.2172783976237658
# 1.14960642822789
# 1.0859984099204518
# final ratio: 1.0261833239783105
# number of iterations: 5
# first attempt: no adjustment
# None
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# ...
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# 5.554098083368473
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-32bdb6f4fb25> in <module>
#      17 print("done merging, running GPE buffer \n")
#      18
# ---> 19 parkGPEs = bufferProp(testParks, "parkGPEs", "PROTECTED_")
#      20
#      21 print("\n done w/ proportional buffer clipping shenanigans")
#
# <ipython-input-20-4f17d4914748> in bufferProp(inShape, saveLoc, UID, proportion, sensitivity, adjustRate)
#      88                 #this is where there is a timesave, for some reason clipping takes forever
#      89                 if ratio != None:
# ---> 90                     buffered = arcpy.Clip_analysis(buffered, clip_by, r"memory\BufferClip")
#      91
#      92                 with arcpy.da.SearchCursor(buffered, [UID_ten, "SHAPE@AREA"]) as SCur:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\analysis.py in Clip(in_features, clip_features, out_feature_class, cluster_tolerance)
#     166     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#     167     try:
# --> 168         retval = convertArcObjectToPythonObject(gp.Clip_analysis(*gp_fixargs((in_features, clip_features, out_feature_class, cluster_tolerance), True)))
#     169         return retval
#     170     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     509         val = getattr(self._gp, attr)
#     510         if callable(val):
# --> 511             return lambda *args: val(*gp_fixargs(args, True))
#     512         else:
#     513             return convertArcObjectToPythonObject(val)
#
# KeyboardInterrupt:

# %%
#find proper shapefiles in case of a crash
shapefiles = []
for root, dirs, files in os.walk("outputs"):
    for file in files:
        if file.endswith(".shp") and not (file.endswith("GPE.shp") 
                                          or file.endswith("BEC.shp") 
                                          or file.endswith("PACE.shp")
                                          or file.endswith("Subzones.shp")):
             shapefiles.append(os.path.join(root, file))
parkList = shapefiles
del shapefiles

# %%
buffered_parks = []
parkGPEs = []
parks_subzoned = []
num_done = 0

# %%
num_files = len(parkList)

for shapefile in parkList[num_done:]:
    clear_output(True)
    
    #if you need to resume from a crash, change num_done in the previous cell to the print statement below - 1
    print(str(num_done + 1), "/", str(num_files))
    print(shapefile)
    print("gpe creation")
    
    buffer_output = bufferProp(shapefile)
    if buffer_output is not None:
        buffered_parks.append(buffer_output[0])
        parkGPEs.append(buffer_output[1])
        clear_output(True)
    
        
        print(str(num_done + 1), "/", str(num_files))
        print(shapefile)
        print("subzones")
        parks_subzoned.append(subzones(buffer_output[0], buffer_output[1]))
    num_done += 1
print("done w/ gpes and subzoning")
# Out:
# 954 / 954
# outputs\ZumtelaBayConservancy\ZumtelaBayConservancy.shp
# subzones
# init
# generating subzones
# generating merged, unsubzoned
# intersecting for subzoned ppa
# making singlepart
# 0 slivers in PPA
# intersecting for subzoned gpe
# making singlepart
# 0 slivers in GPE
# merge eliminated shapefiles
# add myFID field for data aggregation
# done w/ gpes and subzoning

# %% [markdown]
# shapefiles = []
# for root, dirs, files in os.walk("outputs"):
#     for file in files:
#         if file.endswith("GPE.shp"):
#              shapefiles.append(os.path.join(root, file))
# parkGPEs = shapefiles
# buffered_parks = [x[:-8] + x[-4:] for x in shapefiles]
# del shapefiles

# %%
#initialize lists to merge at end
complexesList = []
becList = []
num_files = len(complexNames)
num_done = 0

for Complex in complexNames:
    num_done += 1
    clear_output(True)
    print(str(num_done), "/", str(num_files))
    print(Complex)
    
    becGpeCreation(dissolveComplexes, Complex, "Complex", complexesList)
# Out:
# 25 / 25
# Hakai

# %%
buffered_complexes = []
complexesGPEs = []
complexes_subzoned = []
num_done = 0

# %%
num_files = len(complexesList)

for shapefile in complexesList[num_done:]:
    
    clear_output(True)
    
    
    print(str(num_done + 1), "/", str(num_files))
    print(shapefile)
    
    buffer_output = bufferProp(shapefile)

    if buffer_output is not None:
        clear_output(True)
        print(str(num_done + 1), "/", str(num_files))
        print(shapefile)
        print("subzones")
        
        
        buffered_complexes.append(buffer_output[0])
        complexesGPEs.append(buffer_output[1])
        complexes_subzoned.append(subzones(buffer_output[0], buffer_output[1]))
    num_done += 1
print("done w/ gpes and subzoning")
# Out:
# 25 / 25
# C:\Users\evanmuis.stu\Sync\Masters\Data\outputs\Hakai\Hakai.shp
# math and initialization
# buffering
# ...........done w/ gpes and subzoning

# %% [markdown]
# myDict = {testParks: ("PPA", "Park"),
#           parkGPEs: ("GPE", "Park"),
#           testComplexes: ("PPA", "Complex"),
#           complexesGPEs: ("GPE", "Complex")}
#
# shapeList = list(myDict.keys())
#
# for key, value in myDict.items():
#
#     arcpy.AddField_management(key, "PPA_GPE", "TEXT")
#     arcpy.AddField_management(key, "Park_Complex", "TEXT")
#
#     with arcpy.da.UpdateCursor(key, ["PPA_GPE", "Park_Complex"]) as cursor:
#         for row in cursor:
#             row[0] = value[0]
#             row[1] = value[1]
#             cursor.updateRow(row)
#
# PPA_GPEs = arcpy.Merge_management(shapeList, "PPA_GPEs")
#
#
# parkFieldDict = {'ADMIN_AREA': 'ADMIN_AREA_SID',
#          'PROTECTED_': 'PROTECTED_LANDS_NAME',
#          'PROTECTED1': 'PROTECTED_LANDS_CODE',
#          'PROTECTE_1': 'PROTECTED_LANDS_DESIGNATION',
#          'ORCS_SECON': 'ORCS_SECONDARY',
#          'IUCN_Categ': 'IUCN_Category_Code',
#          'Park_Categ': 'Park_Category_Code',
#          'Establishe': 'Established_Date'}
#
# for key, value in parkFieldDict.items():
#     arcpy.AlterField_management(PPA_GPEs, key, value, value)
#
#
#
# arcpy.DeleteField_management(PPA_GPEs, ["Shape_Leng", "BUFF_DIST", "ORIG_FID"])

# %% [markdown]
# # At this point, GPEs are generated. After this it is clipping the various variables to the PACEs. Theoretically, this could be a different notebook.

# %%
utm_7s = r"H:\utm\UTM_7S"
utm_8s = r"H:\utm\UTM_8S"
utm_9s = r"H:\utm\UTM_9S"
utm_10s = r"H:\utm\UTM_10S"
utm_11s = r"H:\utm\UTM_11S"

ntemsLocs = [utm_7s, utm_8s, utm_9s, utm_10s, utm_11s]
#print(ntemsLocs)

# %%
dist_7s = r"H:\utm\UTM_7S\Results\Change_attribution\Changes_attributed_logic_rules"
dist_8s = r"H:\utm\UTM_8s\Results\Change_attribution\Changes_attributed_logic_rules"
dist_9s = r"H:\utm\UTM_9s\Results\Change_attribution\Changes_attributed_logic_rules"
dist_10s = r"H:\utm\UTM_10s\Results\Change_attribution\Changes_attributed_logic_rules"
dist_11s = r"H:\utm\UTM_11s\Results\Change_attribution\Changes_attributed_logic_rules"

distLocs = [dist_7s, dist_8s, dist_9s, dist_10s, dist_11s]

# %%
for saveFolder, distFolder in zip(ntemsLocs, distLocs):
    
    shpList = []
    for file in os.listdir(distFolder):
        if file.endswith(".shp"):
            shpList.append(os.path.join(distFolder, file))
    
    distSaveLoc = os.path.join(saveFolder, "Change_attribution_logic_rules")
    if not os.path.isdir(distSaveLoc):
        os.makedirs(distSaveLoc)
        
    for shp in shpList:
        splitName = shp.rsplit('\\', 1)[-1].split(".")[0]
        saveName = os.path.join(distSaveLoc, splitName + ".tif")
        #print("running polygon to raster")
        if not os.path.isfile(saveName):
            field_names = [f.name for f in arcpy.ListFields(shp)]

            if "r_class" not in field_names:
                arcpy.AddField_management(shp, "r_class", "SHORT")

            with arcpy.da.UpdateCursor(shp, ["CLASS_LOGI", "r_class"]) as cursor:
                for row in cursor:
                    if row[0] == "Unclassified":
                        row[1] = 1000
                    if row[0] == "Fire":
                        row[1] = 1001
                    if row[0] == "Harvesting":
                        row[1] = 1002
                    if row[0] == "Lcondition":
                        row[1] = 1003
                    if row[0] == "Road":
                        row[1] = 1004
                    if row[0] == "Ag":
                        row[1] = 1005

                    cursor.updateRow(row)
        
        
            arcpy.PolygonToRaster_conversion(shp, "r_class", saveName, cellsize = 30)
        print("done " + saveName)
        
        
    print("done " + saveFolder)
# Out:
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1985.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1986.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1987.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1988.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1989.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1990.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1991.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1992.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1993.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1994.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1995.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1996.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1997.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1998.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_1999.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2000.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2001.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2002.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2003.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2004.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2005.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2006.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2007.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2008.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2009.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2010.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2011.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2012.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2013.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2014.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2015.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2016.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2017.tif
# done H:\utm\UTM_7S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_7S_2018.tif
# done H:\utm\UTM_7S
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1985.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1986.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1987.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1988.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1989.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1990.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1991.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1992.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1993.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1994.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1995.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1996.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1997.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1998.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_1999.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2000.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2001.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2002.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2003.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2004.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2005.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2006.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2007.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2008.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2009.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2010.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2011.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2012.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2013.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2014.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2015.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2016.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2017.tif
# done H:\utm\UTM_8S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_8S_2018.tif
# done H:\utm\UTM_8S
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1985.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1986.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1987.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1988.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1989.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1990.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1991.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1992.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1993.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1994.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1995.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1996.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1997.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1998.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_1999.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2000.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2001.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2002.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2003.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2004.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2005.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2006.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2007.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2008.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2009.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2010.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2011.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2012.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2013.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2014.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2015.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2016.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2017.tif
# done H:\utm\UTM_9S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_9S_2018.tif
# done H:\utm\UTM_9S
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1985.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1986.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1987.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1988.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1989.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1990.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1991.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1992.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1993.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1994.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1995.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1996.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1997.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1998.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_1999.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2000.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2001.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2002.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2003.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2004.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2005.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2006.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2007.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2008.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2009.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2010.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2011.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2012.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2013.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2014.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2015.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2016.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2017.tif
# done H:\utm\UTM_10S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_10S_2018.tif
# done H:\utm\UTM_10S
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1985.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1986.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1987.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1988.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1989.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1990.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1991.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1992.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1993.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1994.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1995.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1996.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1997.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1998.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_1999.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2000.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2001.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2002.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2003.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2004.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2005.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2006.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2007.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2008.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2009.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2010.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2011.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2012.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2013.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2014.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2015.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2016.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2017.tif
# done H:\utm\UTM_11S\Change_attribution_logic_rules\Logic_Rules_Change_Attribution_UTM_11S_2018.tif
# done H:\utm\UTM_11S

# %%
structVars = ["basal_area", "elev_cv", "gross_stem_volume",
             "loreys_height", "percentage_first_returns_above_2m", 
             "total_biomass"]

#unusedStructVars = ["elev_mean", "elev_p95", "elev_stddev", "percentage_first_returns_above_mean"]

# %% [markdown]
# input parameters: years, variables, ppas

# %%
shapefiles = []
for root, dirs, files in os.walk("outputs"):
    for file in files:
        if file.endswith("Subzones.shp"):
             shapefiles.append(os.path.join(root, file))
for_clipping = shapefiles
del shapefiles

# %%
for_clipping
# Out:
# ['outputs\\AdamsLakeMarineParkPoplarPointSite\\AdamsLakeMarineParkPoplarPointSite_PACE_Subzones.shp',
#  'outputs\\AdamsLakeMarineParkRefugeBaySite\\AdamsLakeMarineParkRefugeBaySite_PACE_Subzones.shp',
#  'outputs\\AdamsLakeMarineParkSpillmanBeachSite\\AdamsLakeMarineParkSpillmanBeachSite_PACE_Subzones.shp',
#  'outputs\\AdamsLakeParkBushCreekSite\\AdamsLakeParkBushCreekSite_PACE_Subzones.shp',
#  'outputs\\AKK\\AKK_PACE_Subzones.shp',
#  'outputs\\AlexandraBridgePark\\AlexandraBridgePark_PACE_Subzones.shp',
#  'outputs\\AlezaLakeEcologicalReserve\\AlezaLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\AliceLakePark\\AliceLakePark_PACE_Subzones.shp',
#  'outputs\\AllisonHarbourMarinePark\\AllisonHarbourMarinePark_PACE_Subzones.shp',
#  'outputs\\AllisonLakePark\\AllisonLakePark_PACE_Subzones.shp',
#  'outputs\\AmbroseLakeEcologicalReserve\\AmbroseLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\AnarchistProtectedArea\\AnarchistProtectedArea_PACE_Subzones.shp',
#  'outputs\\AncientForestChunTOhWhudujutPark\\AncientForestChunTOhWhudujutPark_PACE_Subzones.shp',
#  'outputs\\AncientForestChunTOhWhudujutProtectedArea\\AncientForestChunTOhWhudujutProtectedArea_PACE_Subzones.shp',
#  'outputs\\AndersonBayPark\\AndersonBayPark_PACE_Subzones.shp',
#  'outputs\\AndersonFlatsPark\\AndersonFlatsPark_PACE_Subzones.shp',
#  'outputs\\AnsteyHunakwaPark\\AnsteyHunakwaPark_PACE_Subzones.shp',
#  'outputs\\ApodacaPark\\ApodacaPark_PACE_Subzones.shp',
#  'outputs\\ArbutusGrovePark\\ArbutusGrovePark_PACE_Subzones.shp',
#  'outputs\\ArcticPacificLakesPark\\ArcticPacificLakesPark_PACE_Subzones.shp',
#  'outputs\\ArrowLakesParkBurtonSite\\ArrowLakesParkBurtonSite_PACE_Subzones.shp',
#  'outputs\\ArrowLakesParkEagleSite\\ArrowLakesParkEagleSite_PACE_Subzones.shp',
#  'outputs\\ArrowLakesParkFauquierSite\\ArrowLakesParkFauquierSite_PACE_Subzones.shp',
#  'outputs\\ArrowLakesParkShelterBaySite\\ArrowLakesParkShelterBaySite_PACE_Subzones.shp',
#  'outputs\\ArrowstonePark\\ArrowstonePark_PACE_Subzones.shp',
#  'outputs\\ArtlishCavesPark\\ArtlishCavesPark_PACE_Subzones.shp',
#  'outputs\\Atlin\\Atlin_PACE_Subzones.shp',
#  'outputs\\AtnaRiverPark\\AtnaRiverPark_PACE_Subzones.shp',
#  'outputs\\BabineLakeMarineParkHookDeepBaySite\\BabineLakeMarineParkHookDeepBaySite_PACE_Subzones.shp',
#  'outputs\\BabineLakeMarineParkPendletonBaySite\\BabineLakeMarineParkPendletonBaySite_PACE_Subzones.shp',
#  'outputs\\BabineLakeMarineParkPierreCreekSite\\BabineLakeMarineParkPierreCreekSite_PACE_Subzones.shp',
#  'outputs\\BabineLakeMarineParkPinkutCreekSite\\BabineLakeMarineParkPinkutCreekSite_PACE_Subzones.shp',
#  'outputs\\BabineLakeMarineParkSandpointSite\\BabineLakeMarineParkSandpointSite_PACE_Subzones.shp',
#  'outputs\\BabineLakeMarineParkSmithersLandingSite\\BabineLakeMarineParkSmithersLandingSite_PACE_Subzones.shp',
#  'outputs\\BabineMountainsPark\\BabineMountainsPark_PACE_Subzones.shp',
#  'outputs\\BabineMountainsTrailsParkActSection\\BabineMountainsTrailsParkActSection_PACE_Subzones.shp',
#  'outputs\\BabineRiverCorridorPark\\BabineRiverCorridorPark_PACE_Subzones.shp',
#  'outputs\\BambertonPark\\BambertonPark_PACE_Subzones.shp',
#  'outputs\\BananaIslandPark\\BananaIslandPark_PACE_Subzones.shp',
#  'outputs\\BanksNiiLuutiksmConservancy\\BanksNiiLuutiksmConservancy_PACE_Subzones.shp',
#  'outputs\\BearCreekPark\\BearCreekPark_PACE_Subzones.shp',
#  'outputs\\BearGlacierPark\\BearGlacierPark_PACE_Subzones.shp',
#  'outputs\\BearholeLakePark\\BearholeLakePark_PACE_Subzones.shp',
#  'outputs\\BearholeLakeProtectedArea\\BearholeLakeProtectedArea_PACE_Subzones.shp',
#  'outputs\\BearIslandConservancy\\BearIslandConservancy_PACE_Subzones.shp',
#  'outputs\\BeattonPark\\BeattonPark_PACE_Subzones.shp',
#  'outputs\\BeattonRiverPark\\BeattonRiverPark_PACE_Subzones.shp',
#  'outputs\\BeaumontPark\\BeaumontPark_PACE_Subzones.shp',
#  'outputs\\BeaverCreekPark\\BeaverCreekPark_PACE_Subzones.shp',
#  'outputs\\BeaverPointPark\\BeaverPointPark_PACE_Subzones.shp',
#  'outputs\\BeaverValleyPark\\BeaverValleyPark_PACE_Subzones.shp',
#  'outputs\\BecherSPrairiePark\\BecherSPrairiePark_PACE_Subzones.shp',
#  'outputs\\BedardAspenPark\\BedardAspenPark_PACE_Subzones.shp',
#  'outputs\\BednestiLakeEcologicalReserve\\BednestiLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BellaCoolaEstuaryConservancy\\BellaCoolaEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\BellhousePark\\BellhousePark_PACE_Subzones.shp',
#  'outputs\\BigBarLakePark\\BigBarLakePark_PACE_Subzones.shp',
#  'outputs\\BigBasinPark\\BigBasinPark_PACE_Subzones.shp',
#  'outputs\\BigBunsbyMarinePark\\BigBunsbyMarinePark_PACE_Subzones.shp',
#  'outputs\\BigCreekEcologicalReserve\\BigCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BigCreekPark\\BigCreekPark_PACE_Subzones.shp',
#  'outputs\\BigWhiteMountainEcologicalReserve\\BigWhiteMountainEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BijouxFallsPark\\BijouxFallsPark_PACE_Subzones.shp',
#  'outputs\\BirkenheadLakePark\\BirkenheadLakePark_PACE_Subzones.shp',
#  'outputs\\BishopBayMonkeyBeachConservancy\\BishopBayMonkeyBeachConservancy_PACE_Subzones.shp',
#  'outputs\\BishopBayMonkeyBeachCorridorConservancy\\BishopBayMonkeyBeachCorridorConservancy_PACE_Subzones.shp',
#  'outputs\\BlackcombGlacierPark\\BlackcombGlacierPark_PACE_Subzones.shp',
#  'outputs\\BlackwaterCreekEcologicalReserve\\BlackwaterCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BlanketCreekPark\\BlanketCreekPark_PACE_Subzones.shp',
#  'outputs\\BlueDeaseRiversEcologicalReserve\\BlueDeaseRiversEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BlueEarthLakePark\\BlueEarthLakePark_PACE_Subzones.shp',
#  'outputs\\BlueRiverBlackSprucePark\\BlueRiverBlackSprucePark_PACE_Subzones.shp',
#  'outputs\\BlueRiverPinePark\\BlueRiverPinePark_PACE_Subzones.shp',
#  'outputs\\BobtailMountainPark\\BobtailMountainPark_PACE_Subzones.shp',
#  'outputs\\BocockPeakPark\\BocockPeakPark_PACE_Subzones.shp',
#  'outputs\\BodegaRidgePark\\BodegaRidgePark_PACE_Subzones.shp',
#  'outputs\\BonapartePark\\BonapartePark_PACE_Subzones.shp',
#  'outputs\\BoothmanSOxbowPark\\BoothmanSOxbowPark_PACE_Subzones.shp',
#  'outputs\\BorderLakePark\\BorderLakePark_PACE_Subzones.shp',
#  'outputs\\BoulderCreekPark\\BoulderCreekPark_PACE_Subzones.shp',
#  'outputs\\BoundaryCreekPark\\BoundaryCreekPark_PACE_Subzones.shp',
#  'outputs\\BowenIslandEcologicalReserve\\BowenIslandEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BowserEcologicalReserve\\BowserEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BoylePointPark\\BoylePointPark_PACE_Subzones.shp',
#  'outputs\\BoylePointProtectedArea\\BoylePointProtectedArea_PACE_Subzones.shp',
#  'outputs\\BrackendaleEaglesPark\\BrackendaleEaglesPark_PACE_Subzones.shp',
#  'outputs\\BrandywineFallsPark\\BrandywineFallsPark_PACE_Subzones.shp',
#  'outputs\\BrentMountainProtectedArea\\BrentMountainProtectedArea_PACE_Subzones.shp',
#  'outputs\\BridalVeilFallsPark\\BridalVeilFallsPark_PACE_Subzones.shp',
#  'outputs\\BridgeLakePark\\BridgeLakePark_PACE_Subzones.shp',
#  'outputs\\BridgeRiverDeltaPark\\BridgeRiverDeltaPark_PACE_Subzones.shp',
#  'outputs\\BrimRiverHotspringsProtectedArea\\BrimRiverHotspringsProtectedArea_PACE_Subzones.shp',
#  'outputs\\BromleyRockPark\\BromleyRockPark_PACE_Subzones.shp',
#  'outputs\\BroughtonArchipelagoConservancy\\BroughtonArchipelagoConservancy_PACE_Subzones.shp',
#  'outputs\\BrowneLakeEcologicalReserve\\BrowneLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BrowneLakePark\\BrowneLakePark_PACE_Subzones.shp',
#  'outputs\\BuccaneerBayPark\\BuccaneerBayPark_PACE_Subzones.shp',
#  'outputs\\BuckHillsRoadEcologicalReserve\\BuckHillsRoadEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BuckinghorseRiverWaysidePark\\BuckinghorseRiverWaysidePark_PACE_Subzones.shp',
#  'outputs\\BugabooPark\\BugabooPark_PACE_Subzones.shp',
#  'outputs\\BulkleyJunctionPark\\BulkleyJunctionPark_PACE_Subzones.shp',
#  'outputs\\BullCanyonPark\\BullCanyonPark_PACE_Subzones.shp',
#  'outputs\\BurgesJamesGadsdenPark\\BurgesJamesGadsdenPark_PACE_Subzones.shp',
#  'outputs\\BurgoyneBayPark\\BurgoyneBayPark_PACE_Subzones.shp',
#  'outputs\\BurnieRiverProtectedArea\\BurnieRiverProtectedArea_PACE_Subzones.shp',
#  'outputs\\BurnieSheaPark\\BurnieSheaPark_PACE_Subzones.shp',
#  'outputs\\BurnsLakePark\\BurnsLakePark_PACE_Subzones.shp',
#  'outputs\\BurntCabinBogEcologicalReserve\\BurntCabinBogEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\BuseLakeProtectedArea\\BuseLakeProtectedArea_PACE_Subzones.shp',
#  'outputs\\ButlerRidgePark\\ButlerRidgePark_PACE_Subzones.shp',
#  'outputs\\CaligataLakePark\\CaligataLakePark_PACE_Subzones.shp',
#  'outputs\\CallaghanConservancy\\CallaghanConservancy_PACE_Subzones.shp',
#  'outputs\\CallaghanLakePark\\CallaghanLakePark_PACE_Subzones.shp',
#  'outputs\\CallLakePark\\CallLakePark_PACE_Subzones.shp',
#  'outputs\\CampbellBrownKalamalkaLakeEcologicalReserve\\CampbellBrownKalamalkaLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\CanimBeachPark\\CanimBeachPark_PACE_Subzones.shp',
#  'outputs\\CapeScottPark\\CapeScottPark_PACE_Subzones.shp',
#  'outputs\\CardiffMountainEcologicalReserve\\CardiffMountainEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\CaribooNaturePark\\CaribooNaturePark_PACE_Subzones.shp',
#  'outputs\\CaribooRiverPark\\CaribooRiverPark_PACE_Subzones.shp',
#  'outputs\\CarmanahWalbranPark\\CarmanahWalbranPark_PACE_Subzones.shp',
#  'outputs\\CarpLakePark\\CarpLakePark_PACE_Subzones.shp',
#  'outputs\\CarterBayConservancy\\CarterBayConservancy_PACE_Subzones.shp',
#  'outputs\\CastleRockHoodoosPark\\CastleRockHoodoosPark_PACE_Subzones.shp',
#  'outputs\\CatherineCreekEcologicalReserve\\CatherineCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\CattoCreekConservancy\\CattoCreekConservancy_PACE_Subzones.shp',
#  'outputs\\CecilLakeEcologicalReserve\\CecilLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\CedarPointPark\\CedarPointPark_PACE_Subzones.shp',
#  'outputs\\CetanThurstonBayConservancy\\CetanThurstonBayConservancy_PACE_Subzones.shp',
#  'outputs\\ChampionLakesPark\\ChampionLakesPark_PACE_Subzones.shp',
#  'outputs\\CharlieColeCreekEcologicalReserve\\CharlieColeCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\CharlieLakePark\\CharlieLakePark_PACE_Subzones.shp',
#  'outputs\\ChasePark\\ChasePark_PACE_Subzones.shp',
#  'outputs\\ChasmEcologicalReserve\\ChasmEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ChasmPark\\ChasmPark_PACE_Subzones.shp',
#  'outputs\\CheclesetBayEcologicalReserve\\CheclesetBayEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ChemainusRiverPark\\ChemainusRiverPark_PACE_Subzones.shp',
#  'outputs\\ChickensNeckMountainEcologicalReserve\\ChickensNeckMountainEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ChilakoRiverEcologicalReserve\\ChilakoRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ChilliwackRiverPark\\ChilliwackRiverPark_PACE_Subzones.shp',
#  'outputs\\ChoquetteHotSpringsPark\\ChoquetteHotSpringsPark_PACE_Subzones.shp',
#  'outputs\\ChristinaLakePark\\ChristinaLakePark_PACE_Subzones.shp',
#  'outputs\\ChuChuaCottonwoodPark\\ChuChuaCottonwoodPark_PACE_Subzones.shp',
#  'outputs\\ChunamonCreekEcologicalReserve\\ChunamonCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ChurnCreekProtectedArea\\ChurnCreekProtectedArea_PACE_Subzones.shp',
#  'outputs\\CinemaBogEcologicalReserve\\CinemaBogEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\CinnemousunNarrowsPark\\CinnemousunNarrowsPark_PACE_Subzones.shp',
#  'outputs\\ClanninickCreekEcologicalReserve\\ClanninickCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ClaudElliottCreekEcologicalReserve\\ClaudElliottCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ClaudElliottLakePark\\ClaudElliottLakePark_PACE_Subzones.shp',
#  'outputs\\ClayhurstEcologicalReserve\\ClayhurstEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ClayoquotArmPark\\ClayoquotArmPark_PACE_Subzones.shp',
#  'outputs\\ClayoquotPlateauPark\\ClayoquotPlateauPark_PACE_Subzones.shp',
#  'outputs\\ClaytonFallsConservancy\\ClaytonFallsConservancy_PACE_Subzones.shp',
#  'outputs\\ClendinningPark\\ClendinningPark_PACE_Subzones.shp',
#  'outputs\\CloseToTheEdgePark\\CloseToTheEdgePark_PACE_Subzones.shp',
#  'outputs\\CloseToTheEdgeProtectedArea\\CloseToTheEdgeProtectedArea_PACE_Subzones.shp',
#  'outputs\\ClyakEstuaryConservancy\\ClyakEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\CodvilleLagoonConservancy\\CodvilleLagoonConservancy_PACE_Subzones.shp',
#  'outputs\\CodvilleLagoonMarinePark\\CodvilleLagoonMarinePark_PACE_Subzones.shp',
#  'outputs\\CodyCavesPark\\CodyCavesPark_PACE_Subzones.shp',
#  'outputs\\ColdwaterRiverPark\\ColdwaterRiverPark_PACE_Subzones.shp',
#  'outputs\\CollisonPointPark\\CollisonPointPark_PACE_Subzones.shp',
#  'outputs\\ColumbiaLakeEcologicalReserve\\ColumbiaLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ColumbiaLakePark\\ColumbiaLakePark_PACE_Subzones.shp',
#  'outputs\\ComoxLakeBluffsEcologicalReserve\\ComoxLakeBluffsEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ConkleLakePark\\ConkleLakePark_PACE_Subzones.shp',
#  'outputs\\CopperJohnnyPark\\CopperJohnnyPark_PACE_Subzones.shp',
#  'outputs\\CoquihallaCanyonPark\\CoquihallaCanyonPark_PACE_Subzones.shp',
#  'outputs\\CoquihallaRiverPark\\CoquihallaRiverPark_PACE_Subzones.shp',
#  'outputs\\CoquihallaSummitRecreationArea\\CoquihallaSummitRecreationArea_PACE_Subzones.shp',
#  'outputs\\CormorantChannelMarinePark\\CormorantChannelMarinePark_PACE_Subzones.shp',
#  'outputs\\CornwallHillsPark\\CornwallHillsPark_PACE_Subzones.shp',
#  'outputs\\CottonwoodRiverPark\\CottonwoodRiverPark_PACE_Subzones.shp',
#  'outputs\\CougarCanyonEcologicalReserve\\CougarCanyonEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\CowichanRiverPark\\CowichanRiverPark_PACE_Subzones.shp',
#  'outputs\\CrabLakeConservancy\\CrabLakeConservancy_PACE_Subzones.shp',
#  'outputs\\CraigHeadwatersProtectedArea\\CraigHeadwatersProtectedArea_PACE_Subzones.shp',
#  'outputs\\CranstownPointConservancy\\CranstownPointConservancy_PACE_Subzones.shp',
#  'outputs\\CraterLakePark\\CraterLakePark_PACE_Subzones.shp',
#  'outputs\\CrookedRiverPark\\CrookedRiverPark_PACE_Subzones.shp',
#  'outputs\\CrowsnestPark\\CrowsnestPark_PACE_Subzones.shp',
#  'outputs\\CultusLakePark\\CultusLakePark_PACE_Subzones.shp',
#  'outputs\\CumminsLakesPark\\CumminsLakesPark_PACE_Subzones.shp',
#  'outputs\\CumminsRiverProtectedArea\\CumminsRiverProtectedArea_PACE_Subzones.shp',
#  'outputs\\CypressPark\\CypressPark_PACE_Subzones.shp',
#  'outputs\\DahlLakePark\\DahlLakePark_PACE_Subzones.shp',
#  'outputs\\DalaKildalaRiverEstuaryPark\\DalaKildalaRiverEstuaryPark_PACE_Subzones.shp',
#  'outputs\\DamaxyaaConservancy\\DamaxyaaConservancy_PACE_Subzones.shp',
#  'outputs\\DamdochaxProtectedArea\\DamdochaxProtectedArea_PACE_Subzones.shp',
#  'outputs\\DanteSInfernoPark\\DanteSInfernoPark_PACE_Subzones.shp',
#  'outputs\\DarkeLakePark\\DarkeLakePark_PACE_Subzones.shp',
#  'outputs\\DavisLakePark\\DavisLakePark_PACE_Subzones.shp',
#  'outputs\\DawleyPassagePark\\DawleyPassagePark_PACE_Subzones.shp',
#  'outputs\\DeadManSIslandPark\\DeadManSIslandPark_PACE_Subzones.shp',
#  'outputs\\DenisonBonneauPark\\DenisonBonneauPark_PACE_Subzones.shp',
#  'outputs\\DenmanIslandPark\\DenmanIslandPark_PACE_Subzones.shp',
#  'outputs\\DenmanIslandProtectedArea\\DenmanIslandProtectedArea_PACE_Subzones.shp',
#  'outputs\\DesolationSoundMarinePark\\DesolationSoundMarinePark_PACE_Subzones.shp',
#  'outputs\\DetSanEcologicalReserve\\DetSanEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\DianaLakePark\\DianaLakePark_PACE_Subzones.shp',
#  'outputs\\DionisioPointPark\\DionisioPointPark_PACE_Subzones.shp',
#  'outputs\\DixieCoveMarinePark\\DixieCoveMarinePark_PACE_Subzones.shp',
#  'outputs\\DocEnglishBluffEcologicalReserve\\DocEnglishBluffEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\DonnelyLakePark\\DonnelyLakePark_PACE_Subzones.shp',
#  'outputs\\DowningPark\\DowningPark_PACE_Subzones.shp',
#  'outputs\\DragonMountainPark\\DragonMountainPark_PACE_Subzones.shp',
#  'outputs\\DrewryPointPark\\DrewryPointPark_PACE_Subzones.shp',
#  'outputs\\DriftwoodCanyonPark\\DriftwoodCanyonPark_PACE_Subzones.shp',
#  'outputs\\DrizzleLakeEcologicalReserve\\DrizzleLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\DrumbegPark\\DrumbegPark_PACE_Subzones.shp',
#  'outputs\\DryGulchPark\\DryGulchPark_PACE_Subzones.shp',
#  'outputs\\DrywilliamLakeEcologicalReserve\\DrywilliamLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\DuckLakeProtectedArea\\DuckLakeProtectedArea_PACE_Subzones.shp',
#  'outputs\\DuffeyLakePark\\DuffeyLakePark_PACE_Subzones.shp',
#  'outputs\\Dune\\Dune_PACE_Subzones.shp',
#  'outputs\\DunnPeakProtectedArea\\DunnPeakProtectedArea_PACE_Subzones.shp',
#  'outputs\\DuuG\\DuuG_PACE_Subzones.shp',
#  'outputs\\DzawadiKlinakliniEstuaryConservancy\\DzawadiKlinakliniEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\EagleBayPark\\EagleBayPark_PACE_Subzones.shp',
#  'outputs\\EagleRiverPark\\EagleRiverPark_PACE_Subzones.shp',
#  'outputs\\EakinCreekCanyonPark\\EakinCreekCanyonPark_PACE_Subzones.shp',
#  'outputs\\EakinCreekFloodplainPark\\EakinCreekFloodplainPark_PACE_Subzones.shp',
#  'outputs\\EastPinePark\\EastPinePark_PACE_Subzones.shp',
#  'outputs\\EchoBayMarinePark\\EchoBayMarinePark_PACE_Subzones.shp',
#  'outputs\\EchoLakePark\\EchoLakePark_PACE_Subzones.shp',
#  'outputs\\Ecstall\\Ecstall_PACE_Subzones.shp',
#  'outputs\\EcstallHeadwatersConservancy\\EcstallHeadwatersConservancy_PACE_Subzones.shp',
#  'outputs\\EdBirdEstellaLakesPark\\EdBirdEstellaLakesPark_PACE_Subzones.shp',
#  'outputs\\EdgeHillsPark\\EdgeHillsPark_PACE_Subzones.shp',
#  'outputs\\EkwanLakeProtectedArea\\EkwanLakeProtectedArea_PACE_Subzones.shp',
#  'outputs\\ElephantHillPark\\ElephantHillPark_PACE_Subzones.shp',
#  'outputs\\ElevenSistersPark\\ElevenSistersPark_PACE_Subzones.shp',
#  'outputs\\ElkFallsPark\\ElkFallsPark_PACE_Subzones.shp',
#  'outputs\\ElkFallsProtectedArea\\ElkFallsProtectedArea_PACE_Subzones.shp',
#  'outputs\\ElkoPark\\ElkoPark_PACE_Subzones.shp',
#  'outputs\\ElkValleyPark\\ElkValleyPark_PACE_Subzones.shp',
#  'outputs\\EllisIslandEcologicalReserve\\EllisIslandEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\EllisonPark\\EllisonPark_PACE_Subzones.shp',
#  'outputs\\EmarLakesPark\\EmarLakesPark_PACE_Subzones.shp',
#  'outputs\\EmilyLakeConservancy\\EmilyLakeConservancy_PACE_Subzones.shp',
#  'outputs\\EmoryCreekPark\\EmoryCreekPark_PACE_Subzones.shp',
#  'outputs\\EnderbyCliffsPark\\EnderbyCliffsPark_PACE_Subzones.shp',
#  'outputs\\EneasLakesPark\\EneasLakesPark_PACE_Subzones.shp',
#  'outputs\\EnglishLakePark\\EnglishLakePark_PACE_Subzones.shp',
#  'outputs\\EnglishmanRiverFallsPark\\EnglishmanRiverFallsPark_PACE_Subzones.shp',
#  'outputs\\EpsomPark\\EpsomPark_PACE_Subzones.shp',
#  'outputs\\ErgMountainPark\\ErgMountainPark_PACE_Subzones.shp',
#  'outputs\\ErieCreekPark\\ErieCreekPark_PACE_Subzones.shp',
#  'outputs\\EskersPark\\EskersPark_PACE_Subzones.shp',
#  'outputs\\EsteroBasinConservancy\\EsteroBasinConservancy_PACE_Subzones.shp',
#  'outputs\\EsteTiwilhSigurdCreekConservancy\\EsteTiwilhSigurdCreekConservancy_PACE_Subzones.shp',
#  'outputs\\EthelFWilsonMemorialPark\\EthelFWilsonMemorialPark_PACE_Subzones.shp',
#  'outputs\\EuropaLakeConservancy\\EuropaLakeConservancy_PACE_Subzones.shp',
#  'outputs\\EvanoffPark\\EvanoffPark_PACE_Subzones.shp',
#  'outputs\\EvesPark\\EvesPark_PACE_Subzones.shp',
#  'outputs\\ExchamsiksRiverProtectedArea\\ExchamsiksRiverProtectedArea_PACE_Subzones.shp',
#  'outputs\\FerryIslandPark\\FerryIslandPark_PACE_Subzones.shp',
#  'outputs\\FHBarberPark\\FHBarberPark_PACE_Subzones.shp',
#  'outputs\\FieldSLeaseEcologicalReserve\\FieldSLeaseEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\FillongleyPark\\FillongleyPark_PACE_Subzones.shp',
#  'outputs\\FingerTatukPark\\FingerTatukPark_PACE_Subzones.shp',
#  'outputs\\FinnCreekPark\\FinnCreekPark_PACE_Subzones.shp',
#  'outputs\\FinnCreekProtectedArea\\FinnCreekProtectedArea_PACE_Subzones.shp',
#  'outputs\\FintryPark\\FintryPark_PACE_Subzones.shp',
#  'outputs\\FintryProtectedArea\\FintryProtectedArea_PACE_Subzones.shp',
#  'outputs\\FlatLakePark\\FlatLakePark_PACE_Subzones.shp',
#  'outputs\\FloresIslandPark\\FloresIslandPark_PACE_Subzones.shp',
#  'outputs\\Foch\\Foch_PACE_Subzones.shp',
#  'outputs\\FortGeorgeCanyonPark\\FortGeorgeCanyonPark_PACE_Subzones.shp',
#  'outputs\\FortNelsonRiverEcologicalReserve\\FortNelsonRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ForwardHarbourConservancy\\ForwardHarbourConservancy_PACE_Subzones.shp',
#  'outputs\\FossliPark\\FossliPark_PACE_Subzones.shp',
#  'outputs\\FosterArmProtectedArea\\FosterArmProtectedArea_PACE_Subzones.shp',
#  'outputs\\FrancisPointEcologicalReserve\\FrancisPointEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\FrancisPointPark\\FrancisPointPark_PACE_Subzones.shp',
#  'outputs\\FrancoisLakePark\\FrancoisLakePark_PACE_Subzones.shp',
#  'outputs\\FrancoisLakeProtectedArea\\FrancoisLakeProtectedArea_PACE_Subzones.shp',
#  'outputs\\FraserRiverBreaksPark\\FraserRiverBreaksPark_PACE_Subzones.shp',
#  'outputs\\FraserRiverEcologicalReserve\\FraserRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\FraserRiverPark\\FraserRiverPark_PACE_Subzones.shp',
#  'outputs\\FredAntoinePark\\FredAntoinePark_PACE_Subzones.shp',
#  'outputs\\FrenchBarCreekPark\\FrenchBarCreekPark_PACE_Subzones.shp',
#  'outputs\\FrenchBeachPark\\FrenchBeachPark_PACE_Subzones.shp',
#  'outputs\\GabriolaSandsPark\\GabriolaSandsPark_PACE_Subzones.shp',
#  'outputs\\GalianoIslandEcologicalReserve\\GalianoIslandEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\GambleCreekEcologicalReserve\\GambleCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\Gar\\Gar_PACE_Subzones.shp',
#  'outputs\\GardenBayMarinePark\\GardenBayMarinePark_PACE_Subzones.shp',
#  'outputs\\GibsonMarinePark\\GibsonMarinePark_PACE_Subzones.shp',
#  'outputs\\GilnockieCreekEcologicalReserve\\GilnockieCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\GilnockiePark\\GilnockiePark_PACE_Subzones.shp',
#  'outputs\\GilpinGrasslandsPark\\GilpinGrasslandsPark_PACE_Subzones.shp',
#  'outputs\\GingietlCreekEcologicalReserve\\GingietlCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\GiscomePortageTrailProtectedArea\\GiscomePortageTrailProtectedArea_PACE_Subzones.shp',
#  'outputs\\GitxaalaNiiLuutiksmKitkatlaConservancy\\GitxaalaNiiLuutiksmKitkatlaConservancy_PACE_Subzones.shp',
#  'outputs\\GladstonePark\\GladstonePark_PACE_Subzones.shp',
#  'outputs\\GoatCoveConservancy\\GoatCoveConservancy_PACE_Subzones.shp',
#  'outputs\\GoatRangePark\\GoatRangePark_PACE_Subzones.shp',
#  'outputs\\GogukaCreekProtectedArea\\GogukaCreekProtectedArea_PACE_Subzones.shp',
#  'outputs\\GoldenGateXaatYadiAaniConservancy\\GoldenGateXaatYadiAaniConservancy_PACE_Subzones.shp',
#  'outputs\\GoldMuchalatPark\\GoldMuchalatPark_PACE_Subzones.shp',
#  'outputs\\GoldpanPark\\GoldpanPark_PACE_Subzones.shp',
#  'outputs\\GoldstreamPark\\GoldstreamPark_PACE_Subzones.shp',
#  'outputs\\GooseBayConservancy\\GooseBayConservancy_PACE_Subzones.shp',
#  'outputs\\GoosegrassCreekEcologicalReserve\\GoosegrassCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\GordonBayPark\\GordonBayPark_PACE_Subzones.shp',
#  'outputs\\GowllandTodPark\\GowllandTodPark_PACE_Subzones.shp',
#  'outputs\\GrahamLaurierPark\\GrahamLaurierPark_PACE_Subzones.shp',
#  'outputs\\GranbyPark\\GranbyPark_PACE_Subzones.shp',
#  'outputs\\GraylingRiverHotspringsEcologicalReserve\\GraylingRiverHotspringsEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\GraystokesPark\\GraystokesPark_PACE_Subzones.shp',
#  'outputs\\GreatGlacierPark\\GreatGlacierPark_PACE_Subzones.shp',
#  'outputs\\GreenbushLakeProtectedArea\\GreenbushLakeProtectedArea_PACE_Subzones.shp',
#  'outputs\\GreenInletMarinePark\\GreenInletMarinePark_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkArrowheadSite\\GreenLakeParkArrowheadSite_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkBlackBearSite\\GreenLakeParkBlackBearSite_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkBlueSpringSite\\GreenLakeParkBlueSpringSite_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkBoydBaySite\\GreenLakeParkBoydBaySite_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkBucksideHillSite\\GreenLakeParkBucksideHillSite_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkEmeraldBaySite\\GreenLakeParkEmeraldBaySite_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkGreenLakeIslandsSite\\GreenLakeParkGreenLakeIslandsSite_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkLittleArrowSite\\GreenLakeParkLittleArrowSite_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkNolanCreek\\GreenLakeParkNolanCreek_PACE_Subzones.shp',
#  'outputs\\GreenLakeParkSunsetViewSite\\GreenLakeParkSunsetViewSite_PACE_Subzones.shp',
#  'outputs\\GreenstoneMountainPark\\GreenstoneMountainPark_PACE_Subzones.shp',
#  'outputs\\GrohmanNarrowsPark\\GrohmanNarrowsPark_PACE_Subzones.shp',
#  'outputs\\GwillimLakePark\\GwillimLakePark_PACE_Subzones.shp',
#  'outputs\\GwynethLakePark\\GwynethLakePark_PACE_Subzones.shp',
#  'outputs\\HaiLakeMountHermanPark\\HaiLakeMountHermanPark_PACE_Subzones.shp',
#  'outputs\\HaleyLakeEcologicalReserve\\HaleyLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\HalkettBayMarinePark\\HalkettBayMarinePark_PACE_Subzones.shp',
#  'outputs\\HannaTintinaConservancy\\HannaTintinaConservancy_PACE_Subzones.shp',
#  'outputs\\HarbourDudgeonLakesPark\\HarbourDudgeonLakesPark_PACE_Subzones.shp',
#  'outputs\\HardyIslandMarinePark\\HardyIslandMarinePark_PACE_Subzones.shp',
#  'outputs\\HarmonyIslandsMarinePark\\HarmonyIslandsMarinePark_PACE_Subzones.shp',
#  'outputs\\HarryLakeAspenPark\\HarryLakeAspenPark_PACE_Subzones.shp',
#  'outputs\\HaThayimMarinePark\\HaThayimMarinePark_PACE_Subzones.shp',
#  'outputs\\HayneSLeaseEcologicalReserve\\HayneSLeaseEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\HayRiverProtectedArea\\HayRiverProtectedArea_PACE_Subzones.shp',
#  'outputs\\HeatherDinaLakesPark\\HeatherDinaLakesPark_PACE_Subzones.shp',
#  'outputs\\HeightOfTheRockiesPark\\HeightOfTheRockiesPark_PACE_Subzones.shp',
#  'outputs\\HelliwellPark\\HelliwellPark_PACE_Subzones.shp',
#  'outputs\\HemerPark\\HemerPark_PACE_Subzones.shp',
#  'outputs\\HeraldPark\\HeraldPark_PACE_Subzones.shp',
#  'outputs\\HesquiatLakePark\\HesquiatLakePark_PACE_Subzones.shp',
#  'outputs\\HesquiatPeninsulaPark\\HesquiatPeninsulaPark_PACE_Subzones.shp',
#  'outputs\\HighLakesBasinPark\\HighLakesBasinPark_PACE_Subzones.shp',
#  'outputs\\HisnitRiverWatershedProtectedArea\\HisnitRiverWatershedProtectedArea_PACE_Subzones.shp',
#  'outputs\\HitchieCreekPark\\HitchieCreekPark_PACE_Subzones.shp',
#  'outputs\\HoleInTheWallPark\\HoleInTheWallPark_PACE_Subzones.shp',
#  'outputs\\HollidayCreekArchProtectedArea\\HollidayCreekArchProtectedArea_PACE_Subzones.shp',
#  'outputs\\HomathkoEstuaryPark\\HomathkoEstuaryPark_PACE_Subzones.shp',
#  'outputs\\HomathkoRiverTatlayokoProtectedArea\\HomathkoRiverTatlayokoProtectedArea_PACE_Subzones.shp',
#  'outputs\\HoneymoonBayEcologicalReserve\\HoneymoonBayEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\HorneLakeCavesPark\\HorneLakeCavesPark_PACE_Subzones.shp',
#  'outputs\\HornelineCreekPark\\HornelineCreekPark_PACE_Subzones.shp',
#  'outputs\\HorseflyLakePark\\HorseflyLakePark_PACE_Subzones.shp',
#  'outputs\\HotSpringsNoNameCreekConservancy\\HotSpringsNoNameCreekConservancy_PACE_Subzones.shp',
#  'outputs\\HunwadiAhnuhatiBaldConservancy\\HunwadiAhnuhatiBaldConservancy_PACE_Subzones.shp',
#  'outputs\\HylandRiverPark\\HylandRiverPark_PACE_Subzones.shp',
#  'outputs\\ILoqawLakesPlateauConservancy\\ILoqawLakesPlateauConservancy_PACE_Subzones.shp',
#  'outputs\\IndianLakeHitchcockCreekAtChInishaConservan\\IndianLakeHitchcockCreekAtChInishaConservan_PACE_Subzones.shp',
#  'outputs\\InkaneepPark\\InkaneepPark_PACE_Subzones.shp',
#  'outputs\\InlandLakePark\\InlandLakePark_PACE_Subzones.shp',
#  'outputs\\InonoaklinPark\\InonoaklinPark_PACE_Subzones.shp',
#  'outputs\\IskutRiverHotSpringsPark\\IskutRiverHotSpringsPark_PACE_Subzones.shp',
#  'outputs\\Itcha\\Itcha_PACE_Subzones.shp',
#  'outputs\\JackmanFlatsPark\\JackmanFlatsPark_PACE_Subzones.shp',
#  'outputs\\JackpineRemnantProtectedArea\\JackpineRemnantProtectedArea_PACE_Subzones.shp',
#  'outputs\\JacksonNarrowsMarinePark\\JacksonNarrowsMarinePark_PACE_Subzones.shp',
#  'outputs\\JamesChabotPark\\JamesChabotPark_PACE_Subzones.shp',
#  'outputs\\JesseFallsProtectedArea\\JesseFallsProtectedArea_PACE_Subzones.shp',
#  'outputs\\JewelLakePark\\JewelLakePark_PACE_Subzones.shp',
#  'outputs\\JimsmithLakePark\\JimsmithLakePark_PACE_Subzones.shp',
#  'outputs\\JoffreLakesPark\\JoffreLakesPark_PACE_Subzones.shp',
#  'outputs\\JohnstoneCreekPark\\JohnstoneCreekPark_PACE_Subzones.shp',
#  'outputs\\JuanDeFucaPark\\JuanDeFucaPark_PACE_Subzones.shp',
#  'outputs\\JunctionSheepRangePark\\JunctionSheepRangePark_PACE_Subzones.shp',
#  'outputs\\JuniperBeachPark\\JuniperBeachPark_PACE_Subzones.shp',
#  'outputs\\KakwaProtectedArea\\KakwaProtectedArea_PACE_Subzones.shp',
#  'outputs\\KalamalkaLakePark\\KalamalkaLakePark_PACE_Subzones.shp',
#  'outputs\\KatherineTyeEcologicalReserve\\KatherineTyeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\KDistsauskTurtlePointConservancy\\KDistsauskTurtlePointConservancy_PACE_Subzones.shp',
#  'outputs\\KekuliBayPark\\KekuliBayPark_PACE_Subzones.shp',
#  'outputs\\KennedyLakePark\\KennedyLakePark_PACE_Subzones.shp',
#  'outputs\\KennedyRiverBogPark\\KennedyRiverBogPark_PACE_Subzones.shp',
#  'outputs\\KentuckyAlleynePark\\KentuckyAlleynePark_PACE_Subzones.shp',
#  'outputs\\KeremeosColumnsPark\\KeremeosColumnsPark_PACE_Subzones.shp',
#  'outputs\\KettleRiverRecreationArea\\KettleRiverRecreationArea_PACE_Subzones.shp',
#  'outputs\\KhtadaLakeConservancy\\KhtadaLakeConservancy_PACE_Subzones.shp',
#  'outputs\\Khutz\\Khutz_PACE_Subzones.shp',
#  'outputs\\KianukoPark\\KianukoPark_PACE_Subzones.shp',
#  'outputs\\KickinineePark\\KickinineePark_PACE_Subzones.shp',
#  'outputs\\KikomunCreekPark\\KikomunCreekPark_PACE_Subzones.shp',
#  'outputs\\KilbellaEstuaryConservancy\\KilbellaEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\KilbyPark\\KilbyPark_PACE_Subzones.shp',
#  'outputs\\KimsquitEstuaryConservancy\\KimsquitEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\KinaskanLakePark\\KinaskanLakePark_PACE_Subzones.shp',
#  'outputs\\KinBeachPark\\KinBeachPark_PACE_Subzones.shp',
#  'outputs\\KingcomeRiverAtlatziRiverEcologicalReserve\\KingcomeRiverAtlatziRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\KingfisherCreekEcologicalReserve\\KingfisherCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\KingfisherCreekPark\\KingfisherCreekPark_PACE_Subzones.shp',
#  'outputs\\KingGeorgeViPark\\KingGeorgeViPark_PACE_Subzones.shp',
#  'outputs\\KiskatinawPark\\KiskatinawPark_PACE_Subzones.shp',
#  'outputs\\KiskatinawRiverPark\\KiskatinawRiverPark_PACE_Subzones.shp',
#  'outputs\\KitimatRiverPark\\KitimatRiverPark_PACE_Subzones.shp',
#  'outputs\\KitsumkalumLakeNorthProtectedArea\\KitsumkalumLakeNorthProtectedArea_PACE_Subzones.shp',
#  'outputs\\KitsumkalumPark\\KitsumkalumPark_PACE_Subzones.shp',
#  'outputs\\KittyColemanBeachPark\\KittyColemanBeachPark_PACE_Subzones.shp',
#  'outputs\\KitwangaMountainPark\\KitwangaMountainPark_PACE_Subzones.shp',
#  'outputs\\KlanawaRiverEcologicalReserve\\KlanawaRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\KlaskishRiverEcologicalReserve\\KlaskishRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\KleanzaCreekPark\\KleanzaCreekPark_PACE_Subzones.shp',
#  'outputs\\KlinSeZaParkAddition\\KlinSeZaParkAddition_PACE_Subzones.shp',
#  'outputs\\KluaLakesProtectedArea\\KluaLakesProtectedArea_PACE_Subzones.shp',
#  'outputs\\KluskoilLakePark\\KluskoilLakePark_PACE_Subzones.shp',
#  'outputs\\KoeyeConservancy\\KoeyeConservancy_PACE_Subzones.shp',
#  'outputs\\KokaneeCreekPark\\KokaneeCreekPark_PACE_Subzones.shp',
#  'outputs\\KokaneeGlacierPark\\KokaneeGlacierPark_PACE_Subzones.shp',
#  'outputs\\KoksilahRiverPark\\KoksilahRiverPark_PACE_Subzones.shp',
#  'outputs\\KootenayLakeParkCampbellBaySite\\KootenayLakeParkCampbellBaySite_PACE_Subzones.shp',
#  'outputs\\KootenayLakeParkCoffeeCreekSite\\KootenayLakeParkCoffeeCreekSite_PACE_Subzones.shp',
#  'outputs\\KootenayLakeParkDavisCreekSite\\KootenayLakeParkDavisCreekSite_PACE_Subzones.shp',
#  'outputs\\KootenayLakeParkLostLedgeSite\\KootenayLakeParkLostLedgeSite_PACE_Subzones.shp',
#  'outputs\\KootenayLakeParkMidgeCreekSite\\KootenayLakeParkMidgeCreekSite_PACE_Subzones.shp',
#  'outputs\\KotchoLakeEcologicalReserve\\KotchoLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\KotchoLakeVillageSitePark\\KotchoLakeVillageSitePark_PACE_Subzones.shp',
#  'outputs\\KsiXtsAtKwStagooConservancy\\KsiXtsAtKwStagooConservancy_PACE_Subzones.shp',
#  'outputs\\KtisgaidzMacdonaldBayConservancy\\KtisgaidzMacdonaldBayConservancy_PACE_Subzones.shp',
#  'outputs\\KunxalasConservancy\\KunxalasConservancy_PACE_Subzones.shp',
#  'outputs\\KUunaGwaayConservancy\\KUunaGwaayConservancy_PACE_Subzones.shp',
#  'outputs\\KwatnaEstuaryConservancy\\KwatnaEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\KZuzaltTwinTwoConservancy\\KZuzaltTwinTwoConservancy_PACE_Subzones.shp',
#  'outputs\\LacDuBoisGrasslandsProtectedArea\\LacDuBoisGrasslandsProtectedArea_PACE_Subzones.shp',
#  'outputs\\LacLaHachePark\\LacLaHachePark_PACE_Subzones.shp',
#  'outputs\\LacLeJeunePark\\LacLeJeunePark_PACE_Subzones.shp',
#  'outputs\\LadyDouglasDonPeninsulaConservancy\\LadyDouglasDonPeninsulaConservancy_PACE_Subzones.shp',
#  'outputs\\LakelseLakePark\\LakelseLakePark_PACE_Subzones.shp',
#  'outputs\\LakelseLakeWetlandsPark\\LakelseLakeWetlandsPark_PACE_Subzones.shp',
#  'outputs\\LarcomLagoonConservancy\\LarcomLagoonConservancy_PACE_Subzones.shp',
#  'outputs\\LasquetiIslandEcologicalReserve\\LasquetiIslandEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\LauwelnewJohnDeanPark\\LauwelnewJohnDeanPark_PACE_Subzones.shp',
#  'outputs\\LavaForksPark\\LavaForksPark_PACE_Subzones.shp',
#  'outputs\\LawnPointPark\\LawnPointPark_PACE_Subzones.shp',
#  'outputs\\LewCreekEcologicalReserve\\LewCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\Liard\\Liard_PACE_Subzones.shp',
#  'outputs\\LilyPadLakeEcologicalReserve\\LilyPadLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\LittleAndrewsBayMarinePark\\LittleAndrewsBayMarinePark_PACE_Subzones.shp',
#  'outputs\\LittleQualicumFallsPark\\LittleQualicumFallsPark_PACE_Subzones.shp',
#  'outputs\\LiumchenEcologicalReserve\\LiumchenEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\LockhartBeachPark\\LockhartBeachPark_PACE_Subzones.shp',
#  'outputs\\LockhartCreekPark\\LockhartCreekPark_PACE_Subzones.shp',
#  'outputs\\LockhartGordonConservancy\\LockhartGordonConservancy_PACE_Subzones.shp',
#  'outputs\\LongCreekPark\\LongCreekPark_PACE_Subzones.shp',
#  'outputs\\LongIslandConservancy\\LongIslandConservancy_PACE_Subzones.shp',
#  'outputs\\LoonLakePark\\LoonLakePark_PACE_Subzones.shp',
#  'outputs\\LovelandBayPark\\LovelandBayPark_PACE_Subzones.shp',
#  'outputs\\LowerNimpkishPark\\LowerNimpkishPark_PACE_Subzones.shp',
#  'outputs\\LowerRaushProtectedArea\\LowerRaushProtectedArea_PACE_Subzones.shp',
#  'outputs\\LowerSkeenaRiverPark\\LowerSkeenaRiverPark_PACE_Subzones.shp',
#  'outputs\\LowerTsitikaRiverPark\\LowerTsitikaRiverPark_PACE_Subzones.shp',
#  'outputs\\LundmarkBogProtectedArea\\LundmarkBogProtectedArea_PACE_Subzones.shp',
#  'outputs\\MabelLakePark\\MabelLakePark_PACE_Subzones.shp',
#  'outputs\\MachmellConservancy\\MachmellConservancy_PACE_Subzones.shp',
#  'outputs\\MackinnonEskerEcologicalReserve\\MackinnonEskerEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MacmillanPark\\MacmillanPark_PACE_Subzones.shp',
#  'outputs\\MahoneyLakeEcologicalReserve\\MahoneyLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MainLakePark\\MainLakePark_PACE_Subzones.shp',
#  'outputs\\MalaspinaPark\\MalaspinaPark_PACE_Subzones.shp',
#  'outputs\\Mann\\Mann_PACE_Subzones.shp',
#  'outputs\\MansonsLandingPark\\MansonsLandingPark_PACE_Subzones.shp',
#  'outputs\\ManzanitaCoveConservancy\\ManzanitaCoveConservancy_PACE_Subzones.shp',
#  'outputs\\MaquinnaMarinePark\\MaquinnaMarinePark_PACE_Subzones.shp',
#  'outputs\\MaquinnaProtectedArea\\MaquinnaProtectedArea_PACE_Subzones.shp',
#  'outputs\\MaraMeadowsEcologicalReserve\\MaraMeadowsEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MaraMeadowsPark\\MaraMeadowsPark_PACE_Subzones.shp',
#  'outputs\\MaraPark\\MaraPark_PACE_Subzones.shp',
#  'outputs\\MarbleCanyonPark\\MarbleCanyonPark_PACE_Subzones.shp',
#  'outputs\\MarbleRangePark\\MarbleRangePark_PACE_Subzones.shp',
#  'outputs\\MarbleRiverPark\\MarbleRiverPark_PACE_Subzones.shp',
#  'outputs\\MarlCreekPark\\MarlCreekPark_PACE_Subzones.shp',
#  'outputs\\MarthaCreekPark\\MarthaCreekPark_PACE_Subzones.shp',
#  'outputs\\MaxhamishLakeProtectedArea\\MaxhamishLakeProtectedArea_PACE_Subzones.shp',
#  'outputs\\MaxtaktsmAaUnionPassageConservancy\\MaxtaktsmAaUnionPassageConservancy_PACE_Subzones.shp',
#  'outputs\\McconnellLakePark\\McconnellLakePark_PACE_Subzones.shp',
#  'outputs\\McdonaldCreekPark\\McdonaldCreekPark_PACE_Subzones.shp',
#  'outputs\\MemoryIslandPark\\MemoryIslandPark_PACE_Subzones.shp',
#  'outputs\\MeridianRoadVanderhoofEcologicalReserve\\MeridianRoadVanderhoofEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MeziadinLakePark\\MeziadinLakePark_PACE_Subzones.shp',
#  'outputs\\MilliganHillsPark\\MilliganHillsPark_PACE_Subzones.shp',
#  'outputs\\MiracleBeachPark\\MiracleBeachPark_PACE_Subzones.shp',
#  'outputs\\MistyLakeEcologicalReserve\\MistyLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MoberlyLakePark\\MoberlyLakePark_PACE_Subzones.shp',
#  'outputs\\MomichLakesPark\\MomichLakesPark_PACE_Subzones.shp',
#  'outputs\\MonarchMountainAXeegiDeiyiConservancy\\MonarchMountainAXeegiDeiyiConservancy_PACE_Subzones.shp',
#  'outputs\\MonasheePark\\MonasheePark_PACE_Subzones.shp',
#  'outputs\\MonckPark\\MonckPark_PACE_Subzones.shp',
#  'outputs\\MoncktonNiiLuutiksmConservancy\\MoncktonNiiLuutiksmConservancy_PACE_Subzones.shp',
#  'outputs\\MonkmanPark\\MonkmanPark_PACE_Subzones.shp',
#  'outputs\\MontagueHarbourMarinePark\\MontagueHarbourMarinePark_PACE_Subzones.shp',
#  'outputs\\MonteCreekPark\\MonteCreekPark_PACE_Subzones.shp',
#  'outputs\\MonteLakePark\\MonteLakePark_PACE_Subzones.shp',
#  'outputs\\MooseValleyPark\\MooseValleyPark_PACE_Subzones.shp',
#  'outputs\\MordenCollieryPark\\MordenCollieryPark_PACE_Subzones.shp',
#  'outputs\\MoriceLakePark\\MoriceLakePark_PACE_Subzones.shp',
#  'outputs\\MoriceRiverEcologicalReserve\\MoriceRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MorrisseyPark\\MorrisseyPark_PACE_Subzones.shp',
#  'outputs\\MortonLakePark\\MortonLakePark_PACE_Subzones.shp',
#  'outputs\\MountBlanchetPark\\MountBlanchetPark_PACE_Subzones.shp',
#  'outputs\\MountDerbyEcologicalReserve\\MountDerbyEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MountElliottEcologicalReserve\\MountElliottEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MountElphinstonePark\\MountElphinstonePark_PACE_Subzones.shp',
#  'outputs\\MountErskinePark\\MountErskinePark_PACE_Subzones.shp',
#  'outputs\\MountFerniePark\\MountFerniePark_PACE_Subzones.shp',
#  'outputs\\MountGeoffreyEscarpmentPark\\MountGeoffreyEscarpmentPark_PACE_Subzones.shp',
#  'outputs\\MountGriffinEcologicalReserve\\MountGriffinEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MountGriffinPark\\MountGriffinPark_PACE_Subzones.shp',
#  'outputs\\MountMaxwellEcologicalReserve\\MountMaxwellEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MountMaxwellPark\\MountMaxwellPark_PACE_Subzones.shp',
#  'outputs\\MountMintoKIyanConservancy\\MountMintoKIyanConservancy_PACE_Subzones.shp',
#  'outputs\\MountPopePark\\MountPopePark_PACE_Subzones.shp',
#  'outputs\\MountRichardsonPark\\MountRichardsonPark_PACE_Subzones.shp',
#  'outputs\\MountSabineEcologicalReserve\\MountSabineEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MountSavonaPark\\MountSavonaPark_PACE_Subzones.shp',
#  'outputs\\MountSeymourPark\\MountSeymourPark_PACE_Subzones.shp',
#  'outputs\\MountTinsdaleEcologicalReserve\\MountTinsdaleEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MountTuamEcologicalReserve\\MountTuamEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MountTzuhalemEcologicalReserve\\MountTzuhalemEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\MoyieLakePark\\MoyieLakePark_PACE_Subzones.shp',
#  'outputs\\MudLakeDeltaPark\\MudLakeDeltaPark_PACE_Subzones.shp',
#  'outputs\\MudzenchootPark\\MudzenchootPark_PACE_Subzones.shp',
#  'outputs\\MunchoLakePark\\MunchoLakePark_PACE_Subzones.shp',
#  'outputs\\MuqqiwnPeninsulaPark\\MuqqiwnPeninsulaPark_PACE_Subzones.shp',
#  'outputs\\MurrinPark\\MurrinPark_PACE_Subzones.shp',
#  'outputs\\MuscoviteLakesPark\\MuscoviteLakesPark_PACE_Subzones.shp',
#  'outputs\\MyraBellevuePark\\MyraBellevuePark_PACE_Subzones.shp',
#  'outputs\\MyraBellevueProtectedArea\\MyraBellevueProtectedArea_PACE_Subzones.shp',
#  'outputs\\NadinaMountainPark\\NadinaMountainPark_PACE_Subzones.shp',
#  'outputs\\Naik\\Naik_PACE_Subzones.shp',
#  'outputs\\NairnFallsPark\\NairnFallsPark_PACE_Subzones.shp',
#  'outputs\\NalbeelahCreekWetlandsPark\\NalbeelahCreekWetlandsPark_PACE_Subzones.shp',
#  'outputs\\NamuConservancy\\NamuConservancy_PACE_Subzones.shp',
#  'outputs\\NamuCorridorConservancy\\NamuCorridorConservancy_PACE_Subzones.shp',
#  'outputs\\NancyGreenePark\\NancyGreenePark_PACE_Subzones.shp',
#  'outputs\\NarcosliLakeEcologicalReserve\\NarcosliLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\NationLakesPark\\NationLakesPark_PACE_Subzones.shp',
#  'outputs\\NazkoLakePark\\NazkoLakePark_PACE_Subzones.shp',
#  'outputs\\NeAhConservancy\\NeAhConservancy_PACE_Subzones.shp',
#  'outputs\\NechakoCanyonProtectedArea\\NechakoCanyonProtectedArea_PACE_Subzones.shp',
#  'outputs\\NechakoRiverEcologicalReserve\\NechakoRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\NekiteEstuaryConservancy\\NekiteEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\NeneikekhNanikaKidpricePark\\NeneikekhNanikaKidpricePark_PACE_Subzones.shp',
#  'outputs\\NetalzulMeadowsPark\\NetalzulMeadowsPark_PACE_Subzones.shp',
#  'outputs\\NickelPlatePark\\NickelPlatePark_PACE_Subzones.shp',
#  'outputs\\NicolumRiverPark\\NicolumRiverPark_PACE_Subzones.shp',
#  'outputs\\NilkitkwaLakePark\\NilkitkwaLakePark_PACE_Subzones.shp',
#  'outputs\\NimpkishLakePark\\NimpkishLakePark_PACE_Subzones.shp',
#  'outputs\\NimpkishRiverEcologicalReserve\\NimpkishRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\NingunsawPark\\NingunsawPark_PACE_Subzones.shp',
#  'outputs\\NingunsawRiverEcologicalReserve\\NingunsawRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\NisgaAMemorialLavaBedCorridorPaNo\\NisgaAMemorialLavaBedCorridorPaNo_PACE_Subzones.shp',
#  'outputs\\NisgaAMemorialLavaBedCorridorProtectedArea\\NisgaAMemorialLavaBedCorridorProtectedArea_PACE_Subzones.shp',
#  'outputs\\NisgaAMemorialLavaBedPark\\NisgaAMemorialLavaBedPark_PACE_Subzones.shp',
#  'outputs\\NisgaAMemorialLavaBedProtectedArea\\NisgaAMemorialLavaBedProtectedArea_PACE_Subzones.shp',
#  'outputs\\NiskonlithLakePark\\NiskonlithLakePark_PACE_Subzones.shp',
#  'outputs\\NitinatLakeEcologicalReserve\\NitinatLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\NitinatRiverPark\\NitinatRiverPark_PACE_Subzones.shp',
#  'outputs\\NlhaxtenCeriseCreekConservancy\\NlhaxtenCeriseCreekConservancy_PACE_Subzones.shp',
#  'outputs\\NooseseckConservancy\\NooseseckConservancy_PACE_Subzones.shp',
#  'outputs\\NorburyLakePark\\NorburyLakePark_PACE_Subzones.shp',
#  'outputs\\NoRM\\NoRM_PACE_Subzones.shp',
#  'outputs\\NorthSpitConservancy\\NorthSpitConservancy_PACE_Subzones.shp',
#  'outputs\\NorthThompsonIslandsPark\\NorthThompsonIslandsPark_PACE_Subzones.shp',
#  'outputs\\NorthThompsonOxbowsEastPark\\NorthThompsonOxbowsEastPark_PACE_Subzones.shp',
#  'outputs\\NorthThompsonOxbowsJensenIslandPark\\NorthThompsonOxbowsJensenIslandPark_PACE_Subzones.shp',
#  'outputs\\NorthThompsonOxbowsManteauPark\\NorthThompsonOxbowsManteauPark_PACE_Subzones.shp',
#  'outputs\\NorthThompsonRiverPark\\NorthThompsonRiverPark_PACE_Subzones.shp',
#  'outputs\\NuchatlitzPark\\NuchatlitzPark_PACE_Subzones.shp',
#  'outputs\\NunstiPark\\NunstiPark_PACE_Subzones.shp',
#  'outputs\\OctopusIslandsMarinePark\\OctopusIslandsMarinePark_PACE_Subzones.shp',
#  'outputs\\OkanaganLakePark\\OkanaganLakePark_PACE_Subzones.shp',
#  'outputs\\OkanaganMountainPark\\OkanaganMountainPark_PACE_Subzones.shp',
#  'outputs\\OkeoverArmPark\\OkeoverArmPark_PACE_Subzones.shp',
#  'outputs\\OldManLakePark\\OldManLakePark_PACE_Subzones.shp',
#  'outputs\\Om\\Om_PACE_Subzones.shp',
#  'outputs\\OneIslandLakePark\\OneIslandLakePark_PACE_Subzones.shp',
#  'outputs\\OreganaCreekPark\\OreganaCreekPark_PACE_Subzones.shp',
#  'outputs\\OregonJackPark\\OregonJackPark_PACE_Subzones.shp',
#  'outputs\\OspikaConesEcologicalReserve\\OspikaConesEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\OtterLakePark\\OtterLakePark_PACE_Subzones.shp',
#  'outputs\\OtterLakeProtectedArea\\OtterLakeProtectedArea_PACE_Subzones.shp',
#  'outputs\\OwikenoConservancy\\OwikenoConservancy_PACE_Subzones.shp',
#  'outputs\\OwyacumishRiverPark\\OwyacumishRiverPark_PACE_Subzones.shp',
#  'outputs\\PaAatConservancy\\PaAatConservancy_PACE_Subzones.shp',
#  'outputs\\PaarensBeachPark\\PaarensBeachPark_PACE_Subzones.shp',
#  'outputs\\PaintedBluffsPark\\PaintedBluffsPark_PACE_Subzones.shp',
#  'outputs\\ParkerLakeEcologicalReserve\\ParkerLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\PatsukCreekEcologicalReserve\\PatsukCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\PattersonLakePark\\PattersonLakePark_PACE_Subzones.shp',
#  'outputs\\PaulLakePark\\PaulLakePark_PACE_Subzones.shp',
#  'outputs\\PeaceArchPark\\PeaceArchPark_PACE_Subzones.shp',
#  'outputs\\PeaceRiverCorridorPark\\PeaceRiverCorridorPark_PACE_Subzones.shp',
#  'outputs\\PennaskCreekPark\\PennaskCreekPark_PACE_Subzones.shp',
#  'outputs\\PennaskLakePark\\PennaskLakePark_PACE_Subzones.shp',
#  'outputs\\PenroseRiponConservancy\\PenroseRiponConservancy_PACE_Subzones.shp',
#  'outputs\\PetroglyphPark\\PetroglyphPark_PACE_Subzones.shp',
#  'outputs\\PhillipsEstuaryConservancy\\PhillipsEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\PillarPark\\PillarPark_PACE_Subzones.shp',
#  'outputs\\PilotBayPark\\PilotBayPark_PACE_Subzones.shp',
#  'outputs\\PineLeMorayPark\\PineLeMorayPark_PACE_Subzones.shp',
#  'outputs\\PineRiverBreaksPark\\PineRiverBreaksPark_PACE_Subzones.shp',
#  'outputs\\PinkMountainPark\\PinkMountainPark_PACE_Subzones.shp',
#  'outputs\\PinnaclesPark\\PinnaclesPark_PACE_Subzones.shp',
#  'outputs\\PiratesCoveMarinePark\\PiratesCoveMarinePark_PACE_Subzones.shp',
#  'outputs\\PittPolderEcologicalReserve\\PittPolderEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\PlumperCoveMarinePark\\PlumperCoveMarinePark_PACE_Subzones.shp',
#  'outputs\\PorcupineMeadowsPark\\PorcupineMeadowsPark_PACE_Subzones.shp',
#  'outputs\\PorpoiseBayPark\\PorpoiseBayPark_PACE_Subzones.shp',
#  'outputs\\PortageBruleRapidsEcologicalReserve\\PortageBruleRapidsEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\PortageBruleRapidsProtectedArea\\PortageBruleRapidsProtectedArea_PACE_Subzones.shp',
#  'outputs\\PortArthurConservancy\\PortArthurConservancy_PACE_Subzones.shp',
#  'outputs\\PorteauCovePark\\PorteauCovePark_PACE_Subzones.shp',
#  'outputs\\PremierLakePark\\PremierLakePark_PACE_Subzones.shp',
#  'outputs\\PrincessLouisaMarinePark\\PrincessLouisaMarinePark_PACE_Subzones.shp',
#  'outputs\\PritchardPark\\PritchardPark_PACE_Subzones.shp',
#  'outputs\\ProphetRiverHotspringsPark\\ProphetRiverHotspringsPark_PACE_Subzones.shp',
#  'outputs\\ProphetRiverWaysidePark\\ProphetRiverWaysidePark_PACE_Subzones.shp',
#  'outputs\\PrudhommeLakePark\\PrudhommeLakePark_PACE_Subzones.shp',
#  'outputs\\PtarmiganCreekPark\\PtarmiganCreekPark_PACE_Subzones.shp',
#  'outputs\\PtarmiganCreekProtectedArea\\PtarmiganCreekProtectedArea_PACE_Subzones.shp',
#  'outputs\\PukeashunPark\\PukeashunPark_PACE_Subzones.shp',
#  'outputs\\PuntchesakutLakePark\\PuntchesakutLakePark_PACE_Subzones.shp',
#  'outputs\\PuntiIslandPark\\PuntiIslandPark_PACE_Subzones.shp',
#  'outputs\\Purc\\Purc_PACE_Subzones.shp',
#  'outputs\\PurdenLakePark\\PurdenLakePark_PACE_Subzones.shp',
#  'outputs\\PyramidCreekFallsPark\\PyramidCreekFallsPark_PACE_Subzones.shp',
#  'outputs\\QuatsinoPark\\QuatsinoPark_PACE_Subzones.shp',
#  'outputs\\QuesnelLakePark\\QuesnelLakePark_PACE_Subzones.shp',
#  'outputs\\QwalimakUpperBirkenheadConservancy\\QwalimakUpperBirkenheadConservancy_PACE_Subzones.shp',
#  'outputs\\QwiquallaaqBoatBayConservancy\\QwiquallaaqBoatBayConservancy_PACE_Subzones.shp',
#  'outputs\\RaftCovePark\\RaftCovePark_PACE_Subzones.shp',
#  'outputs\\RainbowAlleyPark\\RainbowAlleyPark_PACE_Subzones.shp',
#  'outputs\\RainbowQIwentemPark\\RainbowQIwentemPark_PACE_Subzones.shp',
#  'outputs\\RamCreekEcologicalReserve\\RamCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\RaspberryHarbourEcologicalReserve\\RaspberryHarbourEcologicalReserve_PACE_Subzones.shp',
# ...
#  'outputs\\ShuswapLakeMarineParkBughouseBaySite\\ShuswapLakeMarineParkBughouseBaySite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkCottonwoodBeachSite\\ShuswapLakeMarineParkCottonwoodBeachSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkEncounterPointSite\\ShuswapLakeMarineParkEncounterPointSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkFowlerPointSite\\ShuswapLakeMarineParkFowlerPointSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkHermitBaySite\\ShuswapLakeMarineParkHermitBaySite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkHorseshoeBaySite\\ShuswapLakeMarineParkHorseshoeBaySite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkHungryCoveSite\\ShuswapLakeMarineParkHungryCoveSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkMaraPointSite\\ShuswapLakeMarineParkMaraPointSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkMarblePointSite\\ShuswapLakeMarineParkMarblePointSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkNielsenBeachSite\\ShuswapLakeMarineParkNielsenBeachSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkParadisePointSite\\ShuswapLakeMarineParkParadisePointSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkRobertsBaySite\\ShuswapLakeMarineParkRobertsBaySite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkStIvesSite\\ShuswapLakeMarineParkStIvesSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkSwallSite\\ShuswapLakeMarineParkSwallSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkTiilisBeachSite\\ShuswapLakeMarineParkTiilisBeachSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkTwinBaysSite\\ShuswapLakeMarineParkTwinBaysSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkTwoMileSite\\ShuswapLakeMarineParkTwoMileSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkWoodsLandingSite\\ShuswapLakeMarineParkWoodsLandingSite_PACE_Subzones.shp',
#  'outputs\\ShuswapLakeMarineParkWoodsLandingSouthSit\\ShuswapLakeMarineParkWoodsLandingSouthSit_PACE_Subzones.shp',
#  'outputs\\ShuswapLakePark\\ShuswapLakePark_PACE_Subzones.shp',
#  'outputs\\ShuswapRiverIslandsPark\\ShuswapRiverIslandsPark_PACE_Subzones.shp',
#  'outputs\\SikanniChiefCanyonPark\\SikanniChiefCanyonPark_PACE_Subzones.shp',
#  'outputs\\SikanniChiefFallsProtectedArea\\SikanniChiefFallsProtectedArea_PACE_Subzones.shp',
#  'outputs\\SikanniChiefRiverEcologicalReserve\\SikanniChiefRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\SikanniOldGrowthPark\\SikanniOldGrowthPark_PACE_Subzones.shp',
#  'outputs\\SilverBeachPark\\SilverBeachPark_PACE_Subzones.shp',
#  'outputs\\SilverLakePark\\SilverLakePark_PACE_Subzones.shp',
#  'outputs\\SilverStarPark\\SilverStarPark_PACE_Subzones.shp',
#  'outputs\\SimpsonLakeEastConservancy\\SimpsonLakeEastConservancy_PACE_Subzones.shp',
#  'outputs\\SixMileHillProtectedArea\\SixMileHillProtectedArea_PACE_Subzones.shp',
#  'outputs\\SkahaBluffsPark\\SkahaBluffsPark_PACE_Subzones.shp',
#  'outputs\\SkeenaBankConservancy\\SkeenaBankConservancy_PACE_Subzones.shp',
#  'outputs\\SkeenaRiverEcologicalReserve\\SkeenaRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\SkihistEcologicalReserve\\SkihistEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\SkihistPark\\SkihistPark_PACE_Subzones.shp',
#  'outputs\\SkookumchuckNarrowsPark\\SkookumchuckNarrowsPark_PACE_Subzones.shp',
#  'outputs\\SkookumchuckRapidsPark\\SkookumchuckRapidsPark_PACE_Subzones.shp',
#  'outputs\\SkwahaLakeEcologicalReserve\\SkwahaLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\SleepingBeautyMountainPark\\SleepingBeautyMountainPark_PACE_Subzones.shp',
#  'outputs\\SlimCreekPark\\SlimCreekPark_PACE_Subzones.shp',
#  'outputs\\SmallInletMarinePark\\SmallInletMarinePark_PACE_Subzones.shp',
#  'outputs\\SmallInletProtectedArea\\SmallInletProtectedArea_PACE_Subzones.shp',
#  'outputs\\SmallRiverCavesPark\\SmallRiverCavesPark_PACE_Subzones.shp',
#  'outputs\\SmeltBayPark\\SmeltBayPark_PACE_Subzones.shp',
#  'outputs\\SmithRiverEcologicalReserve\\SmithRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\SmithRiverFallsFortHalkettPark\\SmithRiverFallsFortHalkettPark_PACE_Subzones.shp',
#  'outputs\\SmugglerCoveMarinePark\\SmugglerCoveMarinePark_PACE_Subzones.shp',
#  'outputs\\SoapLakeEcologicalReserve\\SoapLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\SookeMountainPark\\SookeMountainPark_PACE_Subzones.shp',
#  'outputs\\SookePotholesPark\\SookePotholesPark_PACE_Subzones.shp',
#  'outputs\\SouthChilcotinMountainsPark\\SouthChilcotinMountainsPark_PACE_Subzones.shp',
#  'outputs\\SouthOkanaganGrasslandsProtectedArea\\SouthOkanaganGrasslandsProtectedArea_PACE_Subzones.shp',
#  'outputs\\SouthTexadaIslandPark\\SouthTexadaIslandPark_PACE_Subzones.shp',
#  'outputs\\SowcheaBayPark\\SowcheaBayPark_PACE_Subzones.shp',
#  'outputs\\Spats\\Spats_PACE_Subzones.shp',
#  'outputs\\SpatsiziHeadwatersPark\\SpatsiziHeadwatersPark_PACE_Subzones.shp',
#  'outputs\\SpectacleLakePark\\SpectacleLakePark_PACE_Subzones.shp',
#  'outputs\\SpiderLakePark\\SpiderLakePark_PACE_Subzones.shp',
#  'outputs\\SpipiyusPark\\SpipiyusPark_PACE_Subzones.shp',
#  'outputs\\SproatLakePark\\SproatLakePark_PACE_Subzones.shp',
#  'outputs\\SquittyBayPark\\SquittyBayPark_PACE_Subzones.shp',
#  'outputs\\StaffordEstuaryConservancy\\StaffordEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\StagleapPark\\StagleapPark_PACE_Subzones.shp',
#  'outputs\\StairCreekConservancy\\StairCreekConservancy_PACE_Subzones.shp',
#  'outputs\\StampRiverPark\\StampRiverPark_PACE_Subzones.shp',
#  'outputs\\StawamusChiefPark\\StawamusChiefPark_PACE_Subzones.shp',
#  'outputs\\StawamusChiefProtectedArea\\StawamusChiefProtectedArea_PACE_Subzones.shp',
#  'outputs\\SteelheadPark\\SteelheadPark_PACE_Subzones.shp',
#  'outputs\\Stein\\Stein_PACE_Subzones.shp',
#  'outputs\\StemwinderPark\\StemwinderPark_PACE_Subzones.shp',
#  'outputs\\StoyomaCreekEcologicalReserve\\StoyomaCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\Strath\\Strath_PACE_Subzones.shp',
#  'outputs\\StuartLakeMarinePark\\StuartLakeMarinePark_PACE_Subzones.shp',
#  'outputs\\StuartLakePark\\StuartLakePark_PACE_Subzones.shp',
#  'outputs\\StuartRiverParkLowerSite\\StuartRiverParkLowerSite_PACE_Subzones.shp',
#  'outputs\\SueChannelParkLorettaIslandHawkesburyIsla\\SueChannelParkLorettaIslandHawkesburyIsla_PACE_Subzones.shp',
#  'outputs\\SugarbowlGrizzlyDenPark\\SugarbowlGrizzlyDenPark_PACE_Subzones.shp',
#  'outputs\\SugarbowlGrizzlyDenProtectedArea\\SugarbowlGrizzlyDenProtectedArea_PACE_Subzones.shp',
#  'outputs\\SukunkaFallsPark\\SukunkaFallsPark_PACE_Subzones.shp',
#  'outputs\\SummitLakePark\\SummitLakePark_PACE_Subzones.shp',
#  'outputs\\SunbeamCreekEcologicalReserve\\SunbeamCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\SunOkaBeachPark\\SunOkaBeachPark_PACE_Subzones.shp',
#  'outputs\\SurgeNarrowsPark\\SurgeNarrowsPark_PACE_Subzones.shp',
#  'outputs\\Sustut\\Sustut_PACE_Subzones.shp',
#  'outputs\\SutherlandRiverPark\\SutherlandRiverPark_PACE_Subzones.shp',
#  'outputs\\SutherlandRiverProtectedArea\\SutherlandRiverProtectedArea_PACE_Subzones.shp',
#  'outputs\\SuttonPassEcologicalReserve\\SuttonPassEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\SwanCreekProtectedArea\\SwanCreekProtectedArea_PACE_Subzones.shp',
#  'outputs\\SwanLakeKispioxRiverPark\\SwanLakeKispioxRiverPark_PACE_Subzones.shp',
#  'outputs\\SwanLakePark\\SwanLakePark_PACE_Subzones.shp',
#  'outputs\\SwiwsPark\\SwiwsPark_PACE_Subzones.shp',
#  'outputs\\SxwexwnitkwPark\\SxwexwnitkwPark_PACE_Subzones.shp',
#  'outputs\\SydneyInletPark\\SydneyInletPark_PACE_Subzones.shp',
#  'outputs\\SyringaPark\\SyringaPark_PACE_Subzones.shp',
#  'outputs\\TacheedaLakesEcologicalReserve\\TacheedaLakesEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TaChIlaParkAKABoyaLakePark\\TaChIlaParkAKABoyaLakePark_PACE_Subzones.shp',
#  'outputs\\TahsishKwoisPark\\TahsishKwoisPark_PACE_Subzones.shp',
#  'outputs\\TahsishRiverEcologicalReserve\\TahsishRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TaklaMarineParkTaklaWest\\TaklaMarineParkTaklaWest_PACE_Subzones.shp',
#  'outputs\\TantalusPark\\TantalusPark_PACE_Subzones.shp',
#  'outputs\\TarahnePark\\TarahnePark_PACE_Subzones.shp',
#  'outputs\\TaweelPark\\TaweelPark_PACE_Subzones.shp',
#  'outputs\\TaylorArmPark\\TaylorArmPark_PACE_Subzones.shp',
#  'outputs\\TaylorLandingPark\\TaylorLandingPark_PACE_Subzones.shp',
#  'outputs\\TeakerneArmPark\\TeakerneArmPark_PACE_Subzones.shp',
#  'outputs\\TenMileLakePark\\TenMileLakePark_PACE_Subzones.shp',
#  'outputs\\TenMilePointEcologicalReserve\\TenMilePointEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TetrahedronPark\\TetrahedronPark_PACE_Subzones.shp',
#  'outputs\\ThinahteaNorthProtectedArea\\ThinahteaNorthProtectedArea_PACE_Subzones.shp',
#  'outputs\\ThinahteaSouthProtectedArea\\ThinahteaSouthProtectedArea_PACE_Subzones.shp',
#  'outputs\\ThorsenCreekConservancy\\ThorsenCreekConservancy_PACE_Subzones.shp',
#  'outputs\\ThreeSistersLakePark\\ThreeSistersLakePark_PACE_Subzones.shp',
#  'outputs\\ThulmeFallsConservancy\\ThulmeFallsConservancy_PACE_Subzones.shp',
#  'outputs\\ThunderbirdSNestTIitskInPaawats\\ThunderbirdSNestTIitskInPaawats_PACE_Subzones.shp',
#  'outputs\\ThunderHillPark\\ThunderHillPark_PACE_Subzones.shp',
#  'outputs\\ThurstonBayMarinePark\\ThurstonBayMarinePark_PACE_Subzones.shp',
#  'outputs\\TitetownPark\\TitetownPark_PACE_Subzones.shp',
#  'outputs\\ToadRiverHotspringsPark\\ToadRiverHotspringsPark_PACE_Subzones.shp',
#  'outputs\\TodaginSouthSlopePark\\TodaginSouthSlopePark_PACE_Subzones.shp',
#  'outputs\\TopleyPark\\TopleyPark_PACE_Subzones.shp',
#  'outputs\\TopOfTheWorldPark\\TopOfTheWorldPark_PACE_Subzones.shp',
#  'outputs\\TorkelsenLakeEcologicalReserve\\TorkelsenLakeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TranquilCreekPark\\TranquilCreekPark_PACE_Subzones.shp',
#  'outputs\\TranquilleEcologicalReserve\\TranquilleEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TrembleurLakePark\\TrembleurLakePark_PACE_Subzones.shp',
#  'outputs\\TrepanierPark\\TrepanierPark_PACE_Subzones.shp',
#  'outputs\\TrialIslandsEcologicalReserve\\TrialIslandsEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TribuneBayPark\\TribuneBayPark_PACE_Subzones.shp',
#  'outputs\\TroupPassageConservancy\\TroupPassageConservancy_PACE_Subzones.shp',
#  'outputs\\TroutCreekEcologicalReserve\\TroutCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TsaLatlSmokehouseConservancy\\TsaLatlSmokehouseConservancy_PACE_Subzones.shp',
#  'outputs\\TsintsunkoLakesPark\\TsintsunkoLakesPark_PACE_Subzones.shp',
#  'outputs\\TsitikaMountainEcologicalReserve\\TsitikaMountainEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TsitikaRiverEcologicalReserve\\TsitikaRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\TsutswecwPark\\TsutswecwPark_PACE_Subzones.shp',
#  'outputs\\Tsyl\\Tsyl_PACE_Subzones.shp',
#  'outputs\\TudyahLakePark\\TudyahLakePark_PACE_Subzones.shp',
#  'outputs\\TunkwaPark\\TunkwaPark_PACE_Subzones.shp',
#  'outputs\\TutshiLakeTOochAayiConservancy\\TutshiLakeTOochAayiConservancy_PACE_Subzones.shp',
#  'outputs\\TuyaMountainsPark\\TuyaMountainsPark_PACE_Subzones.shp',
#  'outputs\\Tweeds\\Tweeds_PACE_Subzones.shp',
#  'outputs\\TyheeLakePark\\TyheeLakePark_PACE_Subzones.shp',
#  'outputs\\UgwiwaCapeCautionBlundenBayConservancy\\UgwiwaCapeCautionBlundenBayConservancy_PACE_Subzones.shp',
#  'outputs\\UgwiwaCapeCautionConservancy\\UgwiwaCapeCautionConservancy_PACE_Subzones.shp',
#  'outputs\\UnchaMountainRedHillsPark\\UnchaMountainRedHillsPark_PACE_Subzones.shp',
#  'outputs\\UnionPassageMarinePark\\UnionPassageMarinePark_PACE_Subzones.shp',
#  'outputs\\UpperAdamsRiverPark\\UpperAdamsRiverPark_PACE_Subzones.shp',
#  'outputs\\UpperElahoValleyConservancy\\UpperElahoValleyConservancy_PACE_Subzones.shp',
#  'outputs\\UpperLillooetPark\\UpperLillooetPark_PACE_Subzones.shp',
#  'outputs\\UpperRaushProtectedArea\\UpperRaushProtectedArea_PACE_Subzones.shp',
#  'outputs\\UpperRogersKolConservancy\\UpperRogersKolConservancy_PACE_Subzones.shp',
#  'outputs\\UpperSeymourRiverPark\\UpperSeymourRiverPark_PACE_Subzones.shp',
#  'outputs\\UpperShuswapRiverEcologicalReserve\\UpperShuswapRiverEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\UpperSooConservancy\\UpperSooConservancy_PACE_Subzones.shp',
#  'outputs\\UpperVioletCreekPark\\UpperVioletCreekPark_PACE_Subzones.shp',
#  'outputs\\ValhallaPark\\ValhallaPark_PACE_Subzones.shp',
#  'outputs\\VanceCreekEcologicalReserve\\VanceCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\VargasIslandPark\\VargasIslandPark_PACE_Subzones.shp',
#  'outputs\\VaseuxLakePark\\VaseuxLakePark_PACE_Subzones.shp',
#  'outputs\\VaseuxProtectedArea\\VaseuxProtectedArea_PACE_Subzones.shp',
#  'outputs\\VictorLakePark\\VictorLakePark_PACE_Subzones.shp',
#  'outputs\\WahkashPointConservancy\\WahkashPointConservancy_PACE_Subzones.shp',
#  'outputs\\WakemanEstuaryConservancy\\WakemanEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\WakesCovePark\\WakesCovePark_PACE_Subzones.shp',
#  'outputs\\WalesHarbourConservancy\\WalesHarbourConservancy_PACE_Subzones.shp',
#  'outputs\\WalhachinOxbowsPark\\WalhachinOxbowsPark_PACE_Subzones.shp',
#  'outputs\\WalloperLakePark\\WalloperLakePark_PACE_Subzones.shp',
#  'outputs\\WalshCovePark\\WalshCovePark_PACE_Subzones.shp',
#  'outputs\\WapCreekPark\\WapCreekPark_PACE_Subzones.shp',
#  'outputs\\WapitiLakePark\\WapitiLakePark_PACE_Subzones.shp',
#  'outputs\\WardnerPark\\WardnerPark_PACE_Subzones.shp',
#  'outputs\\WasaLakePark\\WasaLakePark_PACE_Subzones.shp',
#  'outputs\\WawleySeymourEstuaryConservancy\\WawleySeymourEstuaryConservancy_PACE_Subzones.shp',
#  'outputs\\WeewanieHotSpringsPark\\WeewanieHotSpringsPark_PACE_Subzones.shp',
#  'outputs\\WendlePark\\WendlePark_PACE_Subzones.shp',
#  'outputs\\WestArmPark\\WestArmPark_PACE_Subzones.shp',
#  'outputs\\WestLakePark\\WestLakePark_PACE_Subzones.shp',
#  'outputs\\WestShawniganLakePark\\WestShawniganLakePark_PACE_Subzones.shp',
#  'outputs\\WestTwinPark\\WestTwinPark_PACE_Subzones.shp',
#  'outputs\\WestTwinProtectedArea\\WestTwinProtectedArea_PACE_Subzones.shp',
#  'outputs\\WestwickLakesEcologicalReserve\\WestwickLakesEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\WeymerCreekPark\\WeymerCreekPark_PACE_Subzones.shp',
#  'outputs\\WG\\WG_PACE_Subzones.shp',
#  'outputs\\WhipsawCreekEcologicalReserve\\WhipsawCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\WhiskersPointPark\\WhiskersPointPark_PACE_Subzones.shp',
#  'outputs\\WhiteLakeGrasslandsProtectedArea\\WhiteLakeGrasslandsProtectedArea_PACE_Subzones.shp',
#  'outputs\\WhiteLakePark\\WhiteLakePark_PACE_Subzones.shp',
#  'outputs\\WhitePelicanPark\\WhitePelicanPark_PACE_Subzones.shp',
#  'outputs\\WhiteRiverPark\\WhiteRiverPark_PACE_Subzones.shp',
#  'outputs\\WhiteswanLakePark\\WhiteswanLakePark_PACE_Subzones.shp',
#  'outputs\\WilkinsonWrightBayConservancy\\WilkinsonWrightBayConservancy_PACE_Subzones.shp',
#  'outputs\\WilliamsCreekEcologicalReserve\\WilliamsCreekEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\WindemereLakePark\\WindemereLakePark_PACE_Subzones.shp',
#  'outputs\\WinterInletConservancy\\WinterInletConservancy_PACE_Subzones.shp',
#  'outputs\\WireCachePark\\WireCachePark_PACE_Subzones.shp',
#  'outputs\\WistariaPark\\WistariaPark_PACE_Subzones.shp',
#  'outputs\\WoodleyRangeEcologicalReserve\\WoodleyRangeEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\WoodMountainSkiPark\\WoodMountainSkiPark_PACE_Subzones.shp',
#  'outputs\\WoodworthLakeConservancy\\WoodworthLakeConservancy_PACE_Subzones.shp',
#  'outputs\\WossLakePark\\WossLakePark_PACE_Subzones.shp',
#  'outputs\\WrinklyFacePark\\WrinklyFacePark_PACE_Subzones.shp',
#  'outputs\\YaaguunGandlaayConservancy\\YaaguunGandlaayConservancy_PACE_Subzones.shp',
#  'outputs\\YaaguunSuuConservancy\\YaaguunSuuConservancy_PACE_Subzones.shp',
#  'outputs\\YahkPark\\YahkPark_PACE_Subzones.shp',
#  'outputs\\YalakomPark\\YalakomPark_PACE_Subzones.shp',
#  'outputs\\YaleGarryOakEcologicalReserve\\YaleGarryOakEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\YardCreekPark\\YardCreekPark_PACE_Subzones.shp',
#  'outputs\\YellowpointBogEcologicalReserve\\YellowpointBogEcologicalReserve_PACE_Subzones.shp',
#  'outputs\\ZumtelaBayConservancy\\ZumtelaBayConservancy_PACE_Subzones.shp']

# %%
inVars = ["HMM", "disturbance", "disturbance_all", "fragstats", "elevation", "nightlights"] + structVars
years = [list(range(1984, 2020))]
ppaList = for_clipping

#inVars = ["disturbance", "HMM", "disturbance_all"]
#ppaList = ['C:\\Users\\evanmuis.stu\\Sync\\Masters\\Data\\outputs\\Gar\\Gar_PACE_Subzones.shp']
years = [2015]

print(inVars)
print(years)
print(ppaList)
# Out:
# ['HMM', 'disturbance', 'disturbance_all', 'fragstats', 'elevation', 'nightlights', 'basal_area', 'elev_cv', 'gross_stem_volume', 'loreys_height', 'percentage_first_returns_above_2m', 'total_biomass']
# [2015]
# ['outputs\\AdamsLakeMarineParkPoplarPointSite\\AdamsLakeMarineParkPoplarPointSite_PACE_Subzones.shp', 'outputs\\AdamsLakeMarineParkRefugeBaySite\\AdamsLakeMarineParkRefugeBaySite_PACE_Subzones.shp', 'outputs\\AdamsLakeMarineParkSpillmanBeachSite\\AdamsLakeMarineParkSpillmanBeachSite_PACE_Subzones.shp', 'outputs\\AdamsLakeParkBushCreekSite\\AdamsLakeParkBushCreekSite_PACE_Subzones.shp', 'outputs\\AKK\\AKK_PACE_Subzones.shp', 'outputs\\AlexandraBridgePark\\AlexandraBridgePark_PACE_Subzones.shp', 'outputs\\AlezaLakeEcologicalReserve\\AlezaLakeEcologicalReserve_PACE_Subzones.shp', 'outputs\\AliceLakePark\\AliceLakePark_PACE_Subzones.shp', 'outputs\\AllisonHarbourMarinePark\\AllisonHarbourMarinePark_PACE_Subzones.shp', 'outputs\\AllisonLakePark\\AllisonLakePark_PACE_Subzones.shp', 'outputs\\AmbroseLakeEcologicalReserve\\AmbroseLakeEcologicalReserve_PACE_Subzones.shp', 'outputs\\AnarchistProtectedArea\\AnarchistProtectedArea_PACE_Subzones.shp', 'outputs\\AncientForestChunTOhWhudujutPark\\AncientForestChunTOhWhudujutPark_PACE_Subzones.shp', 'outputs\\AncientForestChunTOhWhudujutProtectedArea\\AncientForestChunTOhWhudujutProtectedArea_PACE_Subzones.shp', 'outputs\\AndersonBayPark\\AndersonBayPark_PACE_Subzones.shp', 'outputs\\AndersonFlatsPark\\AndersonFlatsPark_PACE_Subzones.shp', 'outputs\\AnsteyHunakwaPark\\AnsteyHunakwaPark_PACE_Subzones.shp', 'outputs\\ApodacaPark\\ApodacaPark_PACE_Subzones.shp', 'outputs\\ArbutusGrovePark\\ArbutusGrovePark_PACE_Subzones.shp', 'outputs\\ArcticPacificLakesPark\\ArcticPacificLakesPark_PACE_Subzones.shp', 'outputs\\ArrowLakesParkBurtonSite\\ArrowLakesParkBurtonSite_PACE_Subzones.shp', 'outputs\\ArrowLakesParkEagleSite\\ArrowLakesParkEagleSite_PACE_Subzones.shp', 'outputs\\ArrowLakesParkFauquierSite\\ArrowLakesParkFauquierSite_PACE_Subzones.shp', 'outputs\\ArrowLakesParkShelterBaySite\\ArrowLakesParkShelterBaySite_PACE_Subzones.shp', 'outputs\\ArrowstonePark\\ArrowstonePark_PACE_Subzones.shp', 'outputs\\ArtlishCavesPark\\ArtlishCavesPark_PACE_Subzones.shp', 'outputs\\Atlin\\Atlin_PACE_Subzones.shp', 'outputs\\AtnaRiverPark\\AtnaRiverPark_PACE_Subzones.shp', 'outputs\\BabineLakeMarineParkHookDeepBaySite\\BabineLakeMarineParkHookDeepBaySite_PACE_Subzones.shp', 'outputs\\BabineLakeMarineParkPendletonBaySite\\BabineLakeMarineParkPendletonBaySite_PACE_Subzones.shp', 'outputs\\BabineLakeMarineParkPierreCreekSite\\BabineLakeMarineParkPierreCreekSite_PACE_Subzones.shp', 'outputs\\BabineLakeMarineParkPinkutCreekSite\\BabineLakeMarineParkPinkutCreekSite_PACE_Subzones.shp', 'outputs\\BabineLakeMarineParkSandpointSite\\BabineLakeMarineParkSandpointSite_PACE_Subzones.shp', 'outputs\\BabineLakeMarineParkSmithersLandingSite\\BabineLakeMarineParkSmithersLandingSite_PACE_Subzones.shp', 'outputs\\BabineMountainsPark\\BabineMountainsPark_PACE_Subzones.shp', 'outputs\\BabineMountainsTrailsParkActSection\\BabineMountainsTrailsParkActSection_PACE_Subzones.shp', 'outputs\\BabineRiverCorridorPark\\BabineRiverCorridorPark_PACE_Subzones.shp', 'outputs\\BambertonPark\\BambertonPark_PACE_Subzones.shp', 'outputs\\BananaIslandPark\\BananaIslandPark_PACE_Subzones.shp', 'outputs\\BanksNiiLuutiksmConservancy\\BanksNiiLuutiksmConservancy_PACE_Subzones.shp', 'outputs\\BearCreekPark\\BearCreekPark_PACE_Subzones.shp', 'outputs\\BearGlacierPark\\BearGlacierPark_PACE_Subzones.shp', 'outputs\\BearholeLakePark\\BearholeLakePark_PACE_Subzones.shp', 'outputs\\BearholeLakeProtectedArea\\BearholeLakeProtectedArea_PACE_Subzones.shp', 'outputs\\BearIslandConservancy\\BearIslandConservancy_PACE_Subzones.shp', 'outputs\\BeattonPark\\BeattonPark_PACE_Subzones.shp', 'outputs\\BeattonRiverPark\\BeattonRiverPark_PACE_Subzones.shp', 'outputs\\BeaumontPark\\BeaumontPark_PACE_Subzones.shp', 'outputs\\BeaverCreekPark\\BeaverCreekPark_PACE_Subzones.shp', 'outputs\\BeaverPointPark\\BeaverPointPark_PACE_Subzones.shp', 'outputs\\BeaverValleyPark\\BeaverValleyPark_PACE_Subzones.shp', 'outputs\\BecherSPrairiePark\\BecherSPrairiePark_PACE_Subzones.shp', 'outputs\ ...

# %%
def ntemsClipping(ppaList, inVars, years):
    
    numZones = 5
    
    x = 1
        
    df = pd.DataFrame(columns = ("park", "var", "year", "exists"))
    
    data = [i for i in it.product(ppaList, inVars, years)]
    num_files = len(data)
    num_done = 0
    
    for values in data:
        num_done += 1
        
        ppa = values[0]
        Var = values[1]
        year = values[2]
    
        ppaName = ppa.rsplit('\\', -1)[-1].split(".")[0].rsplit("_", 1)[0]
            
        VarSave = Var

        parkFolder = os.path.normpath(ppa + os.sep + os.pardir)
        saveFolder = os.path.join(parkFolder, "rasters")

        if not os.path.isdir(saveFolder):
            os.makedirs(os.path.join(saveFolder))
        
        print(str(num_done), "/", str(num_files))
        print(ppaName, Var, year)
        clear_output(wait = True)

        intSaveLocs = []

        finalSaveName = ppaName + "-" + str(year) + "-" + VarSave + ".tif"
        if Var == "elevation":
            finalSaveName = ppaName + "-elevation.tif"
        if Var == "disturbance_all":
            finalSaveName = ppaName + "-disturbance_all.tif"
        if not os.path.isfile(os.path.join(saveFolder, finalSaveName)):

            #for variables that have a single combined layer across bc_albers
            if Var == "fragstats":
                loc = r"H:\Muise\F_noF_other"
                varLoc = os.path.join(loc, "F-noF_BC_" + str(year) + ".tif")
                final = arcpy.sa.ExtractByMask(varLoc, ppa)
                final.save(os.path.join(saveFolder, finalSaveName))

            elif Var == "elevation":
                #elevation
                loc = r"H:\Muise\Elevation"
                varLoc = os.path.join(loc, "DEM_BC.tif")
                paceElev = arcpy.sa.ExtractByMask(varLoc, ppa)
                paceElev.save(os.path.join(saveFolder, finalSaveName))

                #slope
                finalSaveName = ppaName + "-slope.tif"

                paceSlope = Slope(paceElev)
                paceSlope.save(os.path.join(saveFolder, finalSaveName))

                #aspect
                finalSaveName = ppaName + "-aspect.tif"

                paceAspect = Aspect(paceElev)
                paceAspect.save(os.path.join(saveFolder, finalSaveName))

            elif Var == "nightlights":
                loc = r"H:\Muise\nightlights"
                varLoc = os.path.join(loc, "bc-albers_nightlights_" + str(year) + "_reclass.tif")

                final = arcpy.sa.ExtractByMask(varLoc, ppa)
                final.save(os.path.join(saveFolder, finalSaveName))


            #for variables that do not have a single combined layer across bc_albers  
            else:
                for i in range(numZones):

                    zoneNum = str(7 + i) + "S_"
                    zone = "UTM_" + str(7 + i) + "S"
                    zoneDistAll = "UTM" + str(7 + i) + "S"

                    #this has to be changed to work on other variables

                    if Var is "HMM":
                        loc = r"H:\VLCE"
                        varLoc = os.path.join(loc, zone, Var, "LC_Class_HMM_" + zoneNum + str(year) + ".dat")

                    elif Var in structVars:
                        loc = r"H:\Structure"
                        varLoc = os.path.join(loc, zone, Var, "UTM_" + zoneNum + Var + "_" + str(year) + ".dat")

                    elif Var is "disturbance":
                        loc = r"H:\utm"
                        varLoc = os.path.join(loc, zone, "Change_attribution_logic_rules", "Logic_Rules_Change_Attribution_UTM_" + zoneNum + str(year) + ".tif")

                    elif Var is "disturbance_all":
                        loc = r"H:\utm"
                        varLoc = os.path.join(loc, zone, "Results", "Change_attribution", "Attribution_"  + zoneDistAll + "_v2.dat")


                    if not os.path.isfile(os.path.join(saveFolder, finalSaveName)): 
                        #print(varLoc)
                        try:
                            interim = arcpy.sa.ExtractByMask(varLoc, ppa)
                            intSaveLoc = os.path.join(scratch, "test_" + zone + ".tif")
                            interim.save(intSaveLoc)
                            intSaveLocs.append(intSaveLoc)

                        except arcpy.ExecuteError:
                            continue




                #print(intSaveLocs)
                try:
                    if Var in structVars:
                        arcpy.CreateRasterDataset_management(scratch, finalSaveName, "30",
                             "16_BIT_UNSIGNED", number_of_bands = 1)

                        arcpy.Mosaic_management(intSaveLocs, os.path.join(scratch, finalSaveName))
                        final = arcpy.sa.ExtractByMask(os.path.join(scratch, finalSaveName), ppa)
                        forMaskLoc = r"H:\Muise\forestMask"
                        forMaskFile = "ForMask_UTM-7s-11S_" + str(year) + ".tif"
                        yearForMask = os.path.join(forMaskLoc, forMaskFile)
                        final = Times(final, yearForMask)
                        final.save(os.path.join(saveFolder, finalSaveName))

                    elif Var is "disturbance":
                        arcpy.CreateRasterDataset_management(scratch, finalSaveName, "30",
                                 "16_BIT_UNSIGNED", number_of_bands = 1)

                        interimMosaic = arcpy.Mosaic_management(intSaveLocs, os.path.join(scratch, finalSaveName))
                        interimMosaic = Con(IsNull(interimMosaic), 0, interimMosaic)
                        final = arcpy.sa.ExtractByMask(interimMosaic, ppa)

                        final.save(os.path.join(saveFolder, finalSaveName))

                    elif Var is "HMM":
                        arcpy.CreateRasterDataset_management(scratch, finalSaveName, "30",
                                 "16_BIT_UNSIGNED", number_of_bands = 1)

                        arcpy.Mosaic_management(intSaveLocs, os.path.join(scratch, finalSaveName))
                        final = arcpy.sa.ExtractByMask(os.path.join(scratch, finalSaveName), ppa)
                        final.save(os.path.join(saveFolder, finalSaveName))

                    else:
                        arcpy.CreateRasterDataset_management(scratch, finalSaveName, "30",
                                 "16_BIT_UNSIGNED", number_of_bands = 1)

                        arcpy.Mosaic_management(intSaveLocs, os.path.join(scratch, finalSaveName))
                        final = arcpy.sa.ExtractByMask(os.path.join(scratch, finalSaveName), ppa)
                        final.save(os.path.join(saveFolder, finalSaveName))

                    df.loc[x] = (ppaName, VarSave, year, "worked")
                except arcpy.ExecuteError:

                    df.loc[x] = (ppaName, VarSave, year, "did not work")
                    continue
        else:
            df.loc[x] = (ppaName, VarSave, year, "already exists")
        x += 1
                
    return df

# %%
outDf = ntemsClipping(ppaList, inVars, years)
# Out:
# 10944 / 10944
# ZumtelaBayConservancy_PACE total_biomass 2015

# %%
disturbance_dataframe = ntemsClipping(ppaList, ["disturbance"], list(range(1984, 2020)))
# Out:
# did not work
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# <ipython-input-27-de7225815891> in ntemsClipping(ppaList, inVars, years)
#     135
# --> 136                         interimMosaic = arcpy.Mosaic_management(intSaveLocs, os.path.join(scratch, finalSaveName))
#     137                         interimMosaic = Con(IsNull(interimMosaic), 0, interimMosaic)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in Mosaic(inputs, target, mosaic_type, colormap, background_value, nodata_value, onebit_to_eightbit, mosaicking_tolerance, MatchingMethod)
#   16995     except Exception as e:
# > 16996         raise e
#   16997
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in Mosaic(inputs, target, mosaic_type, colormap, background_value, nodata_value, onebit_to_eightbit, mosaicking_tolerance, MatchingMethod)
#   16992     try:
# > 16993         retval = convertArcObjectToPythonObject(gp.Mosaic_management(*gp_fixargs((inputs, target, mosaic_type, colormap, background_value, nodata_value, onebit_to_eightbit, mosaicking_tolerance, MatchingMethod), True)))
#   16994         return retval
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     510         if callable(val):
# --> 511             return lambda *args: val(*gp_fixargs(args, True))
#     512         else:
#
# ExecuteError: Failed to execute. Parameters are not valid.
# ERROR 000735: Input Rasters: Value is required
# Failed to execute (Mosaic).
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-a60cf05dae32> in <module>
# ----> 1 disturbance_dataframe = ntemsClipping(["AKK"], ["disturbance"], list(range(1984, 2020)))
#
# <ipython-input-27-de7225815891> in ntemsClipping(ppaList, inVars, years)
#     159                 except arcpy.ExecuteError:
#     160                     print("did not work")
# --> 161                     time.sleep(2)
#     162                     df.loc[x] = (ppaName, VarSave, year, "did not work")
#     163                     continue
#
# KeyboardInterrupt:

# %%
disturbance_dataframe = ntemsClipping(ppaList, ["disturbance"], [1985])
# Out:
# 912 / 912
# ZumtelaBayConservancy_PACE disturbance 1985

# %%
disturbance_dataframe
# Out:
#                                           park          var  year  exists
# 1      AdamsLakeMarineParkPoplarPointSite_PACE  disturbance  1985  worked
# 2        AdamsLakeMarineParkRefugeBaySite_PACE  disturbance  1985  worked
# 3    AdamsLakeMarineParkSpillmanBeachSite_PACE  disturbance  1985  worked
# 4              AdamsLakeParkBushCreekSite_PACE  disturbance  1985  worked
# 5                                     AKK_PACE  disturbance  1985  worked
# ..                                         ...          ...   ...     ...
# 908                           YalakomPark_PACE  disturbance  1985  worked
# 909         YaleGarryOakEcologicalReserve_PACE  disturbance  1985  worked
# 910                         YardCreekPark_PACE  disturbance  1985  worked
# 911       YellowpointBogEcologicalReserve_PACE  disturbance  1985  worked
# 912                 ZumtelaBayConservancy_PACE  disturbance  1985  worked
#
# [912 rows x 4 columns]

# %% [markdown]
# function to clip the ntems lcc and structure data, all inputs must be in list format

# %% [markdown]
# outDf = ntemsClipping(ppaList, inVars, years)

# %%
pd.set_option("display.max_rows", None)
display(outDf)
# Out:
#                                                    park  \
# 1               AdamsLakeMarineParkPoplarPointSite_PACE
# 2               AdamsLakeMarineParkPoplarPointSite_PACE
# 3               AdamsLakeMarineParkPoplarPointSite_PACE
# 4               AdamsLakeMarineParkPoplarPointSite_PACE
# 5               AdamsLakeMarineParkPoplarPointSite_PACE
# 6               AdamsLakeMarineParkPoplarPointSite_PACE
# 7               AdamsLakeMarineParkPoplarPointSite_PACE
# 8               AdamsLakeMarineParkPoplarPointSite_PACE
# 9               AdamsLakeMarineParkPoplarPointSite_PACE
# 10              AdamsLakeMarineParkPoplarPointSite_PACE
# 11              AdamsLakeMarineParkPoplarPointSite_PACE
# 12              AdamsLakeMarineParkPoplarPointSite_PACE
# 13                AdamsLakeMarineParkRefugeBaySite_PACE
# 14                AdamsLakeMarineParkRefugeBaySite_PACE
# 15                AdamsLakeMarineParkRefugeBaySite_PACE
# 16                AdamsLakeMarineParkRefugeBaySite_PACE
# 17                AdamsLakeMarineParkRefugeBaySite_PACE
# 18                AdamsLakeMarineParkRefugeBaySite_PACE
# 19                AdamsLakeMarineParkRefugeBaySite_PACE
# 20                AdamsLakeMarineParkRefugeBaySite_PACE
# 21                AdamsLakeMarineParkRefugeBaySite_PACE
# 22                AdamsLakeMarineParkRefugeBaySite_PACE
# 23                AdamsLakeMarineParkRefugeBaySite_PACE
# 24                AdamsLakeMarineParkRefugeBaySite_PACE
# 25            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 26            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 27            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 28            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 29            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 30            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 31            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 32            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 33            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 34            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 35            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 36            AdamsLakeMarineParkSpillmanBeachSite_PACE
# 37                      AdamsLakeParkBushCreekSite_PACE
# 38                      AdamsLakeParkBushCreekSite_PACE
# 39                      AdamsLakeParkBushCreekSite_PACE
# 40                      AdamsLakeParkBushCreekSite_PACE
# 41                      AdamsLakeParkBushCreekSite_PACE
# 42                      AdamsLakeParkBushCreekSite_PACE
# 43                      AdamsLakeParkBushCreekSite_PACE
# 44                      AdamsLakeParkBushCreekSite_PACE
# 45                      AdamsLakeParkBushCreekSite_PACE
# 46                      AdamsLakeParkBushCreekSite_PACE
# 47                      AdamsLakeParkBushCreekSite_PACE
# 48                      AdamsLakeParkBushCreekSite_PACE
# 49                                             AKK_PACE
# 50                                             AKK_PACE
# 51                                             AKK_PACE
# 52                                             AKK_PACE
# 53                                             AKK_PACE
# 54                                             AKK_PACE
# 55                                             AKK_PACE
# 56                                             AKK_PACE
# 57                                             AKK_PACE
# 58                                             AKK_PACE
# 59                                             AKK_PACE
# 60                                             AKK_PACE
# 61                             AlexandraBridgePark_PACE
# 62                             AlexandraBridgePark_PACE
# 63                             AlexandraBridgePark_PACE
# 64                             AlexandraBridgePark_PACE
# 65                             AlexandraBridgePark_PACE
# 66                             AlexandraBridgePark_PACE
# 67                             AlexandraBridgePark_PACE
# 68                             AlexandraBridgePark_PACE
# 69                             AlexandraBridgePark_PACE
# 70                             AlexandraBridgePark_PACE
# 71                             AlexandraBridgePark_PACE
# 72                             AlexandraBridgePark_PACE
# 73                      AlezaLakeEcologicalReserve_PACE
# 74                      AlezaLakeEcologicalReserve_PACE
# 75                      AlezaLakeEcologicalReserve_PACE
# 76                      AlezaLakeEcologicalReserve_PACE
# 77                      AlezaLakeEcologicalReserve_PACE
# 78                      AlezaLakeEcologicalReserve_PACE
# 79                      AlezaLakeEcologicalReserve_PACE
# 80                      AlezaLakeEcologicalReserve_PACE
# 81                      AlezaLakeEcologicalReserve_PACE
# 82                      AlezaLakeEcologicalReserve_PACE
# 83                      AlezaLakeEcologicalReserve_PACE
# 84                      AlezaLakeEcologicalReserve_PACE
# 85                                   AliceLakePark_PACE
# 86                                   AliceLakePark_PACE
# 87                                   AliceLakePark_PACE
# 88                                   AliceLakePark_PACE
# 89                                   AliceLakePark_PACE
# 90                                   AliceLakePark_PACE
# 91                                   AliceLakePark_PACE
# 92                                   AliceLakePark_PACE
# 93                                   AliceLakePark_PACE
# 94                                   AliceLakePark_PACE
# 95                                   AliceLakePark_PACE
# 96                                   AliceLakePark_PACE
# 97                        AllisonHarbourMarinePark_PACE
# 98                        AllisonHarbourMarinePark_PACE
# 99                        AllisonHarbourMarinePark_PACE
# 100                       AllisonHarbourMarinePark_PACE
# 101                       AllisonHarbourMarinePark_PACE
# 102                       AllisonHarbourMarinePark_PACE
# 103                       AllisonHarbourMarinePark_PACE
# 104                       AllisonHarbourMarinePark_PACE
# 105                       AllisonHarbourMarinePark_PACE
# 106                       AllisonHarbourMarinePark_PACE
# 107                       AllisonHarbourMarinePark_PACE
# 108                       AllisonHarbourMarinePark_PACE
# 109                                AllisonLakePark_PACE
# 110                                AllisonLakePark_PACE
# 111                                AllisonLakePark_PACE
# 112                                AllisonLakePark_PACE
# 113                                AllisonLakePark_PACE
# 114                                AllisonLakePark_PACE
# 115                                AllisonLakePark_PACE
# 116                                AllisonLakePark_PACE
# 117                                AllisonLakePark_PACE
# 118                                AllisonLakePark_PACE
# 119                                AllisonLakePark_PACE
# 120                                AllisonLakePark_PACE
# 121                   AmbroseLakeEcologicalReserve_PACE
# 122                   AmbroseLakeEcologicalReserve_PACE
# 123                   AmbroseLakeEcologicalReserve_PACE
# 124                   AmbroseLakeEcologicalReserve_PACE
# 125                   AmbroseLakeEcologicalReserve_PACE
# 126                   AmbroseLakeEcologicalReserve_PACE
# 127                   AmbroseLakeEcologicalReserve_PACE
# 128                   AmbroseLakeEcologicalReserve_PACE
# 129                   AmbroseLakeEcologicalReserve_PACE
# 130                   AmbroseLakeEcologicalReserve_PACE
# 131                   AmbroseLakeEcologicalReserve_PACE
# 132                   AmbroseLakeEcologicalReserve_PACE
# 133                         AnarchistProtectedArea_PACE
# 134                         AnarchistProtectedArea_PACE
# 135                         AnarchistProtectedArea_PACE
# 136                         AnarchistProtectedArea_PACE
# 137                         AnarchistProtectedArea_PACE
# 138                         AnarchistProtectedArea_PACE
# 139                         AnarchistProtectedArea_PACE
# 140                         AnarchistProtectedArea_PACE
# 141                         AnarchistProtectedArea_PACE
# 142                         AnarchistProtectedArea_PACE
# 143                         AnarchistProtectedArea_PACE
# 144                         AnarchistProtectedArea_PACE
# 145               AncientForestChunTOhWhudujutPark_PACE
# 146               AncientForestChunTOhWhudujutPark_PACE
# 147               AncientForestChunTOhWhudujutPark_PACE
# 148               AncientForestChunTOhWhudujutPark_PACE
# 149               AncientForestChunTOhWhudujutPark_PACE
# 150               AncientForestChunTOhWhudujutPark_PACE
# 151               AncientForestChunTOhWhudujutPark_PACE
# 152               AncientForestChunTOhWhudujutPark_PACE
# 153               AncientForestChunTOhWhudujutPark_PACE
# 154               AncientForestChunTOhWhudujutPark_PACE
# 155               AncientForestChunTOhWhudujutPark_PACE
# 156               AncientForestChunTOhWhudujutPark_PACE
# 157      AncientForestChunTOhWhudujutProtectedArea_PACE
# 158      AncientForestChunTOhWhudujutProtectedArea_PACE
# 159      AncientForestChunTOhWhudujutProtectedArea_PACE
# 160      AncientForestChunTOhWhudujutProtectedArea_PACE
# 161      AncientForestChunTOhWhudujutProtectedArea_PACE
# 162      AncientForestChunTOhWhudujutProtectedArea_PACE
# 163      AncientForestChunTOhWhudujutProtectedArea_PACE
# 164      AncientForestChunTOhWhudujutProtectedArea_PACE
# 165      AncientForestChunTOhWhudujutProtectedArea_PACE
# 166      AncientForestChunTOhWhudujutProtectedArea_PACE
# 167      AncientForestChunTOhWhudujutProtectedArea_PACE
# 168      AncientForestChunTOhWhudujutProtectedArea_PACE
# 169                                AndersonBayPark_PACE
# 170                                AndersonBayPark_PACE
# 171                                AndersonBayPark_PACE
# 172                                AndersonBayPark_PACE
# 173                                AndersonBayPark_PACE
# 174                                AndersonBayPark_PACE
# 175                                AndersonBayPark_PACE
# 176                                AndersonBayPark_PACE
# 177                                AndersonBayPark_PACE
# 178                                AndersonBayPark_PACE
# 179                                AndersonBayPark_PACE
# 180                                AndersonBayPark_PACE
# 181                              AndersonFlatsPark_PACE
# 182                              AndersonFlatsPark_PACE
# 183                              AndersonFlatsPark_PACE
# 184                              AndersonFlatsPark_PACE
# 185                              AndersonFlatsPark_PACE
# 186                              AndersonFlatsPark_PACE
# 187                              AndersonFlatsPark_PACE
# 188                              AndersonFlatsPark_PACE
# 189                              AndersonFlatsPark_PACE
# 190                              AndersonFlatsPark_PACE
# 191                              AndersonFlatsPark_PACE
# 192                              AndersonFlatsPark_PACE
# 193                              AnsteyHunakwaPark_PACE
# 194                              AnsteyHunakwaPark_PACE
# 195                              AnsteyHunakwaPark_PACE
# 196                              AnsteyHunakwaPark_PACE
# 197                              AnsteyHunakwaPark_PACE
# 198                              AnsteyHunakwaPark_PACE
# 199                              AnsteyHunakwaPark_PACE
# 200                              AnsteyHunakwaPark_PACE
# 201                              AnsteyHunakwaPark_PACE
# 202                              AnsteyHunakwaPark_PACE
# 203                              AnsteyHunakwaPark_PACE
# 204                              AnsteyHunakwaPark_PACE
# 205                                    ApodacaPark_PACE
# 206                                    ApodacaPark_PACE
# 207                                    ApodacaPark_PACE
# 208                                    ApodacaPark_PACE
# 209                                    ApodacaPark_PACE
# 210                                    ApodacaPark_PACE
# 211                                    ApodacaPark_PACE
# 212                                    ApodacaPark_PACE
# 213                                    ApodacaPark_PACE
# 214                                    ApodacaPark_PACE
# 215                                    ApodacaPark_PACE
# 216                                    ApodacaPark_PACE
# 217                               ArbutusGrovePark_PACE
# 218                               ArbutusGrovePark_PACE
# 219                               ArbutusGrovePark_PACE
# 220                               ArbutusGrovePark_PACE
# 221                               ArbutusGrovePark_PACE
# 222                               ArbutusGrovePark_PACE
# 223                               ArbutusGrovePark_PACE
# 224                               ArbutusGrovePark_PACE
# 225                               ArbutusGrovePark_PACE
# 226                               ArbutusGrovePark_PACE
# 227                               ArbutusGrovePark_PACE
# 228                               ArbutusGrovePark_PACE
# 229                         ArcticPacificLakesPark_PACE
# 230                         ArcticPacificLakesPark_PACE
# 231                         ArcticPacificLakesPark_PACE
# 232                         ArcticPacificLakesPark_PACE
# 233                         ArcticPacificLakesPark_PACE
# 234                         ArcticPacificLakesPark_PACE
# 235                         ArcticPacificLakesPark_PACE
# 236                         ArcticPacificLakesPark_PACE
# 237                         ArcticPacificLakesPark_PACE
# 238                         ArcticPacificLakesPark_PACE
# 239                         ArcticPacificLakesPark_PACE
# 240                         ArcticPacificLakesPark_PACE
# 241                       ArrowLakesParkBurtonSite_PACE
# 242                       ArrowLakesParkBurtonSite_PACE
# 243                       ArrowLakesParkBurtonSite_PACE
# 244                       ArrowLakesParkBurtonSite_PACE
# 245                       ArrowLakesParkBurtonSite_PACE
# 246                       ArrowLakesParkBurtonSite_PACE
# 247                       ArrowLakesParkBurtonSite_PACE
# 248                       ArrowLakesParkBurtonSite_PACE
# 249                       ArrowLakesParkBurtonSite_PACE
# 250                       ArrowLakesParkBurtonSite_PACE
# 251                       ArrowLakesParkBurtonSite_PACE
# 252                       ArrowLakesParkBurtonSite_PACE
# 253                        ArrowLakesParkEagleSite_PACE
# 254                        ArrowLakesParkEagleSite_PACE
# 255                        ArrowLakesParkEagleSite_PACE
# 256                        ArrowLakesParkEagleSite_PACE
# 257                        ArrowLakesParkEagleSite_PACE
# 258                        ArrowLakesParkEagleSite_PACE
# 259                        ArrowLakesParkEagleSite_PACE
# 260                        ArrowLakesParkEagleSite_PACE
# 261                        ArrowLakesParkEagleSite_PACE
# 262                        ArrowLakesParkEagleSite_PACE
# 263                        ArrowLakesParkEagleSite_PACE
# 264                        ArrowLakesParkEagleSite_PACE
# 265                     ArrowLakesParkFauquierSite_PACE
# 266                     ArrowLakesParkFauquierSite_PACE
# 267                     ArrowLakesParkFauquierSite_PACE
# 268                     ArrowLakesParkFauquierSite_PACE
# 269                     ArrowLakesParkFauquierSite_PACE
# 270                     ArrowLakesParkFauquierSite_PACE
# 271                     ArrowLakesParkFauquierSite_PACE
# 272                     ArrowLakesParkFauquierSite_PACE
# 273                     ArrowLakesParkFauquierSite_PACE
# 274                     ArrowLakesParkFauquierSite_PACE
# 275                     ArrowLakesParkFauquierSite_PACE
# 276                     ArrowLakesParkFauquierSite_PACE
# 277                   ArrowLakesParkShelterBaySite_PACE
# 278                   ArrowLakesParkShelterBaySite_PACE
# 279                   ArrowLakesParkShelterBaySite_PACE
# 280                   ArrowLakesParkShelterBaySite_PACE
# 281                   ArrowLakesParkShelterBaySite_PACE
# 282                   ArrowLakesParkShelterBaySite_PACE
# 283                   ArrowLakesParkShelterBaySite_PACE
# 284                   ArrowLakesParkShelterBaySite_PACE
# 285                   ArrowLakesParkShelterBaySite_PACE
# 286                   ArrowLakesParkShelterBaySite_PACE
# 287                   ArrowLakesParkShelterBaySite_PACE
# 288                   ArrowLakesParkShelterBaySite_PACE
# 289                                 ArrowstonePark_PACE
# 290                                 ArrowstonePark_PACE
# 291                                 ArrowstonePark_PACE
# 292                                 ArrowstonePark_PACE
# 293                                 ArrowstonePark_PACE
# 294                                 ArrowstonePark_PACE
# 295                                 ArrowstonePark_PACE
# 296                                 ArrowstonePark_PACE
# 297                                 ArrowstonePark_PACE
# 298                                 ArrowstonePark_PACE
# 299                                 ArrowstonePark_PACE
# 300                                 ArrowstonePark_PACE
# 301                               ArtlishCavesPark_PACE
# 302                               ArtlishCavesPark_PACE
# 303                               ArtlishCavesPark_PACE
# 304                               ArtlishCavesPark_PACE
# 305                               ArtlishCavesPark_PACE
# 306                               ArtlishCavesPark_PACE
# 307                               ArtlishCavesPark_PACE
# 308                               ArtlishCavesPark_PACE
# 309                               ArtlishCavesPark_PACE
# 310                               ArtlishCavesPark_PACE
# 311                               ArtlishCavesPark_PACE
# 312                               ArtlishCavesPark_PACE
# 313                                          Atlin_PACE
# 314                                          Atlin_PACE
# 315                                          Atlin_PACE
# 316                                          Atlin_PACE
# 317                                          Atlin_PACE
# 318                                          Atlin_PACE
# 319                                          Atlin_PACE
# 320                                          Atlin_PACE
# 321                                          Atlin_PACE
# 322                                          Atlin_PACE
# 323                                          Atlin_PACE
# 324                                          Atlin_PACE
# 325                                  AtnaRiverPark_PACE
# 326                                  AtnaRiverPark_PACE
# 327                                  AtnaRiverPark_PACE
# 328                                  AtnaRiverPark_PACE
# 329                                  AtnaRiverPark_PACE
# 330                                  AtnaRiverPark_PACE
# 331                                  AtnaRiverPark_PACE
# 332                                  AtnaRiverPark_PACE
# 333                                  AtnaRiverPark_PACE
# 334                                  AtnaRiverPark_PACE
# 335                                  AtnaRiverPark_PACE
# 336                                  AtnaRiverPark_PACE
# 337            BabineLakeMarineParkHookDeepBaySite_PACE
# 338            BabineLakeMarineParkHookDeepBaySite_PACE
# 339            BabineLakeMarineParkHookDeepBaySite_PACE
# 340            BabineLakeMarineParkHookDeepBaySite_PACE
# 341            BabineLakeMarineParkHookDeepBaySite_PACE
# 342            BabineLakeMarineParkHookDeepBaySite_PACE
# 343            BabineLakeMarineParkHookDeepBaySite_PACE
# 344            BabineLakeMarineParkHookDeepBaySite_PACE
# 345            BabineLakeMarineParkHookDeepBaySite_PACE
# 346            BabineLakeMarineParkHookDeepBaySite_PACE
# 347            BabineLakeMarineParkHookDeepBaySite_PACE
# 348            BabineLakeMarineParkHookDeepBaySite_PACE
# 349           BabineLakeMarineParkPendletonBaySite_PACE
# 350           BabineLakeMarineParkPendletonBaySite_PACE
# 351           BabineLakeMarineParkPendletonBaySite_PACE
# 352           BabineLakeMarineParkPendletonBaySite_PACE
# 353           BabineLakeMarineParkPendletonBaySite_PACE
# 354           BabineLakeMarineParkPendletonBaySite_PACE
# 355           BabineLakeMarineParkPendletonBaySite_PACE
# 356           BabineLakeMarineParkPendletonBaySite_PACE
# 357           BabineLakeMarineParkPendletonBaySite_PACE
# 358           BabineLakeMarineParkPendletonBaySite_PACE
# 359           BabineLakeMarineParkPendletonBaySite_PACE
# 360           BabineLakeMarineParkPendletonBaySite_PACE
# 361            BabineLakeMarineParkPierreCreekSite_PACE
# 362            BabineLakeMarineParkPierreCreekSite_PACE
# 363            BabineLakeMarineParkPierreCreekSite_PACE
# 364            BabineLakeMarineParkPierreCreekSite_PACE
# 365            BabineLakeMarineParkPierreCreekSite_PACE
# 366            BabineLakeMarineParkPierreCreekSite_PACE
# 367            BabineLakeMarineParkPierreCreekSite_PACE
# 368            BabineLakeMarineParkPierreCreekSite_PACE
# 369            BabineLakeMarineParkPierreCreekSite_PACE
# 370            BabineLakeMarineParkPierreCreekSite_PACE
# 371            BabineLakeMarineParkPierreCreekSite_PACE
# 372            BabineLakeMarineParkPierreCreekSite_PACE
# 373            BabineLakeMarineParkPinkutCreekSite_PACE
# 374            BabineLakeMarineParkPinkutCreekSite_PACE
# 375            BabineLakeMarineParkPinkutCreekSite_PACE
# 376            BabineLakeMarineParkPinkutCreekSite_PACE
# 377            BabineLakeMarineParkPinkutCreekSite_PACE
# 378            BabineLakeMarineParkPinkutCreekSite_PACE
# 379            BabineLakeMarineParkPinkutCreekSite_PACE
# 380            BabineLakeMarineParkPinkutCreekSite_PACE
# 381            BabineLakeMarineParkPinkutCreekSite_PACE
# 382            BabineLakeMarineParkPinkutCreekSite_PACE
# 383            BabineLakeMarineParkPinkutCreekSite_PACE
# 384            BabineLakeMarineParkPinkutCreekSite_PACE
# 385              BabineLakeMarineParkSandpointSite_PACE
# 386              BabineLakeMarineParkSandpointSite_PACE
# 387              BabineLakeMarineParkSandpointSite_PACE
# 388              BabineLakeMarineParkSandpointSite_PACE
# 389              BabineLakeMarineParkSandpointSite_PACE
# 390              BabineLakeMarineParkSandpointSite_PACE
# 391              BabineLakeMarineParkSandpointSite_PACE
# 392              BabineLakeMarineParkSandpointSite_PACE
# 393              BabineLakeMarineParkSandpointSite_PACE
# 394              BabineLakeMarineParkSandpointSite_PACE
# 395              BabineLakeMarineParkSandpointSite_PACE
# 396              BabineLakeMarineParkSandpointSite_PACE
# 397        BabineLakeMarineParkSmithersLandingSite_PACE
# 398        BabineLakeMarineParkSmithersLandingSite_PACE
# 399        BabineLakeMarineParkSmithersLandingSite_PACE
# 400        BabineLakeMarineParkSmithersLandingSite_PACE
# 401        BabineLakeMarineParkSmithersLandingSite_PACE
# 402        BabineLakeMarineParkSmithersLandingSite_PACE
# 403        BabineLakeMarineParkSmithersLandingSite_PACE
# 404        BabineLakeMarineParkSmithersLandingSite_PACE
# 405        BabineLakeMarineParkSmithersLandingSite_PACE
# 406        BabineLakeMarineParkSmithersLandingSite_PACE
# 407        BabineLakeMarineParkSmithersLandingSite_PACE
# 408        BabineLakeMarineParkSmithersLandingSite_PACE
# 409                            BabineMountainsPark_PACE
# 410                            BabineMountainsPark_PACE
# 411                            BabineMountainsPark_PACE
# 412                            BabineMountainsPark_PACE
# 413                            BabineMountainsPark_PACE
# 414                            BabineMountainsPark_PACE
# 415                            BabineMountainsPark_PACE
# 416                            BabineMountainsPark_PACE
# 417                            BabineMountainsPark_PACE
# 418                            BabineMountainsPark_PACE
# 419                            BabineMountainsPark_PACE
# 420                            BabineMountainsPark_PACE
# 421            BabineMountainsTrailsParkActSection_PACE
# 422            BabineMountainsTrailsParkActSection_PACE
# 423            BabineMountainsTrailsParkActSection_PACE
# 424            BabineMountainsTrailsParkActSection_PACE
# 425            BabineMountainsTrailsParkActSection_PACE
# 426            BabineMountainsTrailsParkActSection_PACE
# 427            BabineMountainsTrailsParkActSection_PACE
# 428            BabineMountainsTrailsParkActSection_PACE
# 429            BabineMountainsTrailsParkActSection_PACE
# 430            BabineMountainsTrailsParkActSection_PACE
# 431            BabineMountainsTrailsParkActSection_PACE
# 432            BabineMountainsTrailsParkActSection_PACE
# 433                        BabineRiverCorridorPark_PACE
# 434                        BabineRiverCorridorPark_PACE
# 435                        BabineRiverCorridorPark_PACE
# 436                        BabineRiverCorridorPark_PACE
# 437                        BabineRiverCorridorPark_PACE
# 438                        BabineRiverCorridorPark_PACE
# 439                        BabineRiverCorridorPark_PACE
# 440                        BabineRiverCorridorPark_PACE
# 441                        BabineRiverCorridorPark_PACE
# 442                        BabineRiverCorridorPark_PACE
# 443                        BabineRiverCorridorPark_PACE
# 444                        BabineRiverCorridorPark_PACE
# 445                                  BambertonPark_PACE
# 446                                  BambertonPark_PACE
# 447                                  BambertonPark_PACE
# 448                                  BambertonPark_PACE
# 449                                  BambertonPark_PACE
# 450                                  BambertonPark_PACE
# 451                                  BambertonPark_PACE
# 452                                  BambertonPark_PACE
# 453                                  BambertonPark_PACE
# 454                                  BambertonPark_PACE
# 455                                  BambertonPark_PACE
# 456                                  BambertonPark_PACE
# 457                               BananaIslandPark_PACE
# 458                               BananaIslandPark_PACE
# 459                               BananaIslandPark_PACE
# 460                               BananaIslandPark_PACE
# 461                               BananaIslandPark_PACE
# 462                               BananaIslandPark_PACE
# 463                               BananaIslandPark_PACE
# 464                               BananaIslandPark_PACE
# 465                               BananaIslandPark_PACE
# 466                               BananaIslandPark_PACE
# 467                               BananaIslandPark_PACE
# 468                               BananaIslandPark_PACE
# 469                    BanksNiiLuutiksmConservancy_PACE
# 470                    BanksNiiLuutiksmConservancy_PACE
# 471                    BanksNiiLuutiksmConservancy_PACE
# 472                    BanksNiiLuutiksmConservancy_PACE
# 473                    BanksNiiLuutiksmConservancy_PACE
# 474                    BanksNiiLuutiksmConservancy_PACE
# 475                    BanksNiiLuutiksmConservancy_PACE
# 476                    BanksNiiLuutiksmConservancy_PACE
# 477                    BanksNiiLuutiksmConservancy_PACE
# 478                    BanksNiiLuutiksmConservancy_PACE
# 479                    BanksNiiLuutiksmConservancy_PACE
# 480                    BanksNiiLuutiksmConservancy_PACE
# 481                                  BearCreekPark_PACE
# 482                                  BearCreekPark_PACE
# 483                                  BearCreekPark_PACE
# 484                                  BearCreekPark_PACE
# 485                                  BearCreekPark_PACE
# 486                                  BearCreekPark_PACE
# 487                                  BearCreekPark_PACE
# 488                                  BearCreekPark_PACE
# 489                                  BearCreekPark_PACE
# 490                                  BearCreekPark_PACE
# 491                                  BearCreekPark_PACE
# 492                                  BearCreekPark_PACE
# 493                                BearGlacierPark_PACE
# 494                                BearGlacierPark_PACE
# 495                                BearGlacierPark_PACE
# 496                                BearGlacierPark_PACE
# 497                                BearGlacierPark_PACE
# 498                                BearGlacierPark_PACE
# 499                                BearGlacierPark_PACE
# 500                                BearGlacierPark_PACE
# 501                                BearGlacierPark_PACE
# 502                                BearGlacierPark_PACE
# 503                                BearGlacierPark_PACE
# 504                                BearGlacierPark_PACE
# 505                               BearholeLakePark_PACE
# 506                               BearholeLakePark_PACE
# 507                               BearholeLakePark_PACE
# 508                               BearholeLakePark_PACE
# 509                               BearholeLakePark_PACE
# 510                               BearholeLakePark_PACE
# 511                               BearholeLakePark_PACE
# 512                               BearholeLakePark_PACE
# 513                               BearholeLakePark_PACE
# 514                               BearholeLakePark_PACE
# 515                               BearholeLakePark_PACE
# 516                               BearholeLakePark_PACE
# 517                      BearholeLakeProtectedArea_PACE
# 518                      BearholeLakeProtectedArea_PACE
# 519                      BearholeLakeProtectedArea_PACE
# 520                      BearholeLakeProtectedArea_PACE
# 521                      BearholeLakeProtectedArea_PACE
# 522                      BearholeLakeProtectedArea_PACE
# 523                      BearholeLakeProtectedArea_PACE
# 524                      BearholeLakeProtectedArea_PACE
# 525                      BearholeLakeProtectedArea_PACE
# 526                      BearholeLakeProtectedArea_PACE
# 527                      BearholeLakeProtectedArea_PACE
# 528                      BearholeLakeProtectedArea_PACE
# 529                          BearIslandConservancy_PACE
# 530                          BearIslandConservancy_PACE
# 531                          BearIslandConservancy_PACE
# 532                          BearIslandConservancy_PACE
# 533                          BearIslandConservancy_PACE
# 534                          BearIslandConservancy_PACE
# 535                          BearIslandConservancy_PACE
# 536                          BearIslandConservancy_PACE
# 537                          BearIslandConservancy_PACE
# 538                          BearIslandConservancy_PACE
# 539                          BearIslandConservancy_PACE
# 540                          BearIslandConservancy_PACE
# 541                                    BeattonPark_PACE
# 542                                    BeattonPark_PACE
# 543                                    BeattonPark_PACE
# 544                                    BeattonPark_PACE
# 545                                    BeattonPark_PACE
# 546                                    BeattonPark_PACE
# 547                                    BeattonPark_PACE
# 548                                    BeattonPark_PACE
# 549                                    BeattonPark_PACE
# 550                                    BeattonPark_PACE
# 551                                    BeattonPark_PACE
# 552                                    BeattonPark_PACE
# 553                               BeattonRiverPark_PACE
# 554                               BeattonRiverPark_PACE
# 555                               BeattonRiverPark_PACE
# 556                               BeattonRiverPark_PACE
# 557                               BeattonRiverPark_PACE
# 558                               BeattonRiverPark_PACE
# 559                               BeattonRiverPark_PACE
# 560                               BeattonRiverPark_PACE
# 561                               BeattonRiverPark_PACE
# 562                               BeattonRiverPark_PACE
# 563                               BeattonRiverPark_PACE
# 564                               BeattonRiverPark_PACE
# 565                                   BeaumontPark_PACE
# 566                                   BeaumontPark_PACE
# 567                                   BeaumontPark_PACE
# 568                                   BeaumontPark_PACE
# 569                                   BeaumontPark_PACE
# 570                                   BeaumontPark_PACE
# 571                                   BeaumontPark_PACE
# 572                                   BeaumontPark_PACE
# 573                                   BeaumontPark_PACE
# 574                                   BeaumontPark_PACE
# 575                                   BeaumontPark_PACE
# 576                                   BeaumontPark_PACE
# 577                                BeaverCreekPark_PACE
# 578                                BeaverCreekPark_PACE
# 579                                BeaverCreekPark_PACE
# 580                                BeaverCreekPark_PACE
# 581                                BeaverCreekPark_PACE
# 582                                BeaverCreekPark_PACE
# 583                                BeaverCreekPark_PACE
# 584                                BeaverCreekPark_PACE
# 585                                BeaverCreekPark_PACE
# 586                                BeaverCreekPark_PACE
# 587                                BeaverCreekPark_PACE
# 588                                BeaverCreekPark_PACE
# 589                                BeaverPointPark_PACE
# 590                                BeaverPointPark_PACE
# 591                                BeaverPointPark_PACE
# 592                                BeaverPointPark_PACE
# 593                                BeaverPointPark_PACE
# 594                                BeaverPointPark_PACE
# 595                                BeaverPointPark_PACE
# 596                                BeaverPointPark_PACE
# 597                                BeaverPointPark_PACE
# 598                                BeaverPointPark_PACE
# 599                                BeaverPointPark_PACE
# 600                                BeaverPointPark_PACE
# 601                               BeaverValleyPark_PACE
# 602                               BeaverValleyPark_PACE
# 603                               BeaverValleyPark_PACE
# 604                               BeaverValleyPark_PACE
# 605                               BeaverValleyPark_PACE
# 606                               BeaverValleyPark_PACE
# 607                               BeaverValleyPark_PACE
# 608                               BeaverValleyPark_PACE
# 609                               BeaverValleyPark_PACE
# 610                               BeaverValleyPark_PACE
# 611                               BeaverValleyPark_PACE
# 612                               BeaverValleyPark_PACE
# 613                             BecherSPrairiePark_PACE
# 614                             BecherSPrairiePark_PACE
# 615                             BecherSPrairiePark_PACE
# 616                             BecherSPrairiePark_PACE
# 617                             BecherSPrairiePark_PACE
# 618                             BecherSPrairiePark_PACE
# 619                             BecherSPrairiePark_PACE
# 620                             BecherSPrairiePark_PACE
# 621                             BecherSPrairiePark_PACE
# 622                             BecherSPrairiePark_PACE
# 623                             BecherSPrairiePark_PACE
# 624                             BecherSPrairiePark_PACE
# 625                                BedardAspenPark_PACE
# 626                                BedardAspenPark_PACE
# 627                                BedardAspenPark_PACE
# 628                                BedardAspenPark_PACE
# 629                                BedardAspenPark_PACE
# 630                                BedardAspenPark_PACE
# 631                                BedardAspenPark_PACE
# 632                                BedardAspenPark_PACE
# 633                                BedardAspenPark_PACE
# 634                                BedardAspenPark_PACE
# 635                                BedardAspenPark_PACE
# 636                                BedardAspenPark_PACE
# 637                  BednestiLakeEcologicalReserve_PACE
# 638                  BednestiLakeEcologicalReserve_PACE
# 639                  BednestiLakeEcologicalReserve_PACE
# 640                  BednestiLakeEcologicalReserve_PACE
# 641                  BednestiLakeEcologicalReserve_PACE
# 642                  BednestiLakeEcologicalReserve_PACE
# 643                  BednestiLakeEcologicalReserve_PACE
# 644                  BednestiLakeEcologicalReserve_PACE
# 645                  BednestiLakeEcologicalReserve_PACE
# 646                  BednestiLakeEcologicalReserve_PACE
# 647                  BednestiLakeEcologicalReserve_PACE
# 648                  BednestiLakeEcologicalReserve_PACE
# 649                   BellaCoolaEstuaryConservancy_PACE
# 650                   BellaCoolaEstuaryConservancy_PACE
# 651                   BellaCoolaEstuaryConservancy_PACE
# 652                   BellaCoolaEstuaryConservancy_PACE
# 653                   BellaCoolaEstuaryConservancy_PACE
# 654                   BellaCoolaEstuaryConservancy_PACE
# 655                   BellaCoolaEstuaryConservancy_PACE
# 656                   BellaCoolaEstuaryConservancy_PACE
# 657                   BellaCoolaEstuaryConservancy_PACE
# 658                   BellaCoolaEstuaryConservancy_PACE
# 659                   BellaCoolaEstuaryConservancy_PACE
# 660                   BellaCoolaEstuaryConservancy_PACE
# 661                                  BellhousePark_PACE
# 662                                  BellhousePark_PACE
# 663                                  BellhousePark_PACE
# 664                                  BellhousePark_PACE
# 665                                  BellhousePark_PACE
# 666                                  BellhousePark_PACE
# 667                                  BellhousePark_PACE
# 668                                  BellhousePark_PACE
# 669                                  BellhousePark_PACE
# 670                                  BellhousePark_PACE
# 671                                  BellhousePark_PACE
# 672                                  BellhousePark_PACE
# 673                                 BigBarLakePark_PACE
# 674                                 BigBarLakePark_PACE
# 675                                 BigBarLakePark_PACE
# 676                                 BigBarLakePark_PACE
# 677                                 BigBarLakePark_PACE
# 678                                 BigBarLakePark_PACE
# 679                                 BigBarLakePark_PACE
# 680                                 BigBarLakePark_PACE
# 681                                 BigBarLakePark_PACE
# 682                                 BigBarLakePark_PACE
# 683                                 BigBarLakePark_PACE
# 684                                 BigBarLakePark_PACE
# 685                                   BigBasinPark_PACE
# 686                                   BigBasinPark_PACE
# 687                                   BigBasinPark_PACE
# 688                                   BigBasinPark_PACE
# 689                                   BigBasinPark_PACE
# 690                                   BigBasinPark_PACE
# 691                                   BigBasinPark_PACE
# 692                                   BigBasinPark_PACE
# 693                                   BigBasinPark_PACE
# 694                                   BigBasinPark_PACE
# 695                                   BigBasinPark_PACE
# 696                                   BigBasinPark_PACE
# 697                            BigBunsbyMarinePark_PACE
# 698                            BigBunsbyMarinePark_PACE
# 699                            BigBunsbyMarinePark_PACE
# 700                            BigBunsbyMarinePark_PACE
# 701                            BigBunsbyMarinePark_PACE
# 702                            BigBunsbyMarinePark_PACE
# 703                            BigBunsbyMarinePark_PACE
# 704                            BigBunsbyMarinePark_PACE
# 705                            BigBunsbyMarinePark_PACE
# 706                            BigBunsbyMarinePark_PACE
# 707                            BigBunsbyMarinePark_PACE
# 708                            BigBunsbyMarinePark_PACE
# 709                      BigCreekEcologicalReserve_PACE
# 710                      BigCreekEcologicalReserve_PACE
# 711                      BigCreekEcologicalReserve_PACE
# 712                      BigCreekEcologicalReserve_PACE
# 713                      BigCreekEcologicalReserve_PACE
# 714                      BigCreekEcologicalReserve_PACE
# 715                      BigCreekEcologicalReserve_PACE
# 716                      BigCreekEcologicalReserve_PACE
# 717                      BigCreekEcologicalReserve_PACE
# 718                      BigCreekEcologicalReserve_PACE
# 719                      BigCreekEcologicalReserve_PACE
# 720                      BigCreekEcologicalReserve_PACE
# 721                                   BigCreekPark_PACE
# 722                                   BigCreekPark_PACE
# 723                                   BigCreekPark_PACE
# 724                                   BigCreekPark_PACE
# 725                                   BigCreekPark_PACE
# 726                                   BigCreekPark_PACE
# 727                                   BigCreekPark_PACE
# 728                                   BigCreekPark_PACE
# 729                                   BigCreekPark_PACE
# 730                                   BigCreekPark_PACE
# 731                                   BigCreekPark_PACE
# 732                                   BigCreekPark_PACE
# 733              BigWhiteMountainEcologicalReserve_PACE
# 734              BigWhiteMountainEcologicalReserve_PACE
# 735              BigWhiteMountainEcologicalReserve_PACE
# 736              BigWhiteMountainEcologicalReserve_PACE
# 737              BigWhiteMountainEcologicalReserve_PACE
# 738              BigWhiteMountainEcologicalReserve_PACE
# 739              BigWhiteMountainEcologicalReserve_PACE
# 740              BigWhiteMountainEcologicalReserve_PACE
# 741              BigWhiteMountainEcologicalReserve_PACE
# 742              BigWhiteMountainEcologicalReserve_PACE
# 743              BigWhiteMountainEcologicalReserve_PACE
# 744              BigWhiteMountainEcologicalReserve_PACE
# 745                                BijouxFallsPark_PACE
# 746                                BijouxFallsPark_PACE
# 747                                BijouxFallsPark_PACE
# 748                                BijouxFallsPark_PACE
# 749                                BijouxFallsPark_PACE
# 750                                BijouxFallsPark_PACE
# 751                                BijouxFallsPark_PACE
# 752                                BijouxFallsPark_PACE
# 753                                BijouxFallsPark_PACE
# 754                                BijouxFallsPark_PACE
# 755                                BijouxFallsPark_PACE
# 756                                BijouxFallsPark_PACE
# 757                             BirkenheadLakePark_PACE
# 758                             BirkenheadLakePark_PACE
# 759                             BirkenheadLakePark_PACE
# 760                             BirkenheadLakePark_PACE
# 761                             BirkenheadLakePark_PACE
# 762                             BirkenheadLakePark_PACE
# 763                             BirkenheadLakePark_PACE
# 764                             BirkenheadLakePark_PACE
# 765                             BirkenheadLakePark_PACE
# 766                             BirkenheadLakePark_PACE
# 767                             BirkenheadLakePark_PACE
# 768                             BirkenheadLakePark_PACE
# 769                BishopBayMonkeyBeachConservancy_PACE
# 770                BishopBayMonkeyBeachConservancy_PACE
# 771                BishopBayMonkeyBeachConservancy_PACE
# 772                BishopBayMonkeyBeachConservancy_PACE
# 773                BishopBayMonkeyBeachConservancy_PACE
# 774                BishopBayMonkeyBeachConservancy_PACE
# 775                BishopBayMonkeyBeachConservancy_PACE
# 776                BishopBayMonkeyBeachConservancy_PACE
# 777                BishopBayMonkeyBeachConservancy_PACE
# 778                BishopBayMonkeyBeachConservancy_PACE
# 779                BishopBayMonkeyBeachConservancy_PACE
# 780                BishopBayMonkeyBeachConservancy_PACE
# 781        BishopBayMonkeyBeachCorridorConservancy_PACE
# 782        BishopBayMonkeyBeachCorridorConservancy_PACE
# 783        BishopBayMonkeyBeachCorridorConservancy_PACE
# 784        BishopBayMonkeyBeachCorridorConservancy_PACE
# 785        BishopBayMonkeyBeachCorridorConservancy_PACE
# 786        BishopBayMonkeyBeachCorridorConservancy_PACE
# 787        BishopBayMonkeyBeachCorridorConservancy_PACE
# 788        BishopBayMonkeyBeachCorridorConservancy_PACE
# 789        BishopBayMonkeyBeachCorridorConservancy_PACE
# 790        BishopBayMonkeyBeachCorridorConservancy_PACE
# 791        BishopBayMonkeyBeachCorridorConservancy_PACE
# 792        BishopBayMonkeyBeachCorridorConservancy_PACE
# 793                           BlackcombGlacierPark_PACE
# 794                           BlackcombGlacierPark_PACE
# 795                           BlackcombGlacierPark_PACE
# 796                           BlackcombGlacierPark_PACE
# 797                           BlackcombGlacierPark_PACE
# 798                           BlackcombGlacierPark_PACE
# 799                           BlackcombGlacierPark_PACE
# 800                           BlackcombGlacierPark_PACE
# 801                           BlackcombGlacierPark_PACE
# 802                           BlackcombGlacierPark_PACE
# 803                           BlackcombGlacierPark_PACE
# 804                           BlackcombGlacierPark_PACE
# 805               BlackwaterCreekEcologicalReserve_PACE
# 806               BlackwaterCreekEcologicalReserve_PACE
# 807               BlackwaterCreekEcologicalReserve_PACE
# 808               BlackwaterCreekEcologicalReserve_PACE
# 809               BlackwaterCreekEcologicalReserve_PACE
# 810               BlackwaterCreekEcologicalReserve_PACE
# 811               BlackwaterCreekEcologicalReserve_PACE
# 812               BlackwaterCreekEcologicalReserve_PACE
# ...
# 10618                      loreys_height  2015          worked
# 10619  percentage_first_returns_above_2m  2015          worked
# 10620                      total_biomass  2015          worked
# 10621                                HMM  2015          worked
# 10622                        disturbance  2015          worked
# 10623                    disturbance_all  2015          worked
# 10627                         basal_area  2015          worked
# 10628                            elev_cv  2015          worked
# 10629                  gross_stem_volume  2015          worked
# 10630                      loreys_height  2015          worked
# 10631  percentage_first_returns_above_2m  2015          worked
# 10632                      total_biomass  2015          worked
# 10633                                HMM  2015          worked
# 10634                        disturbance  2015          worked
# 10635                    disturbance_all  2015          worked
# 10639                         basal_area  2015          worked
# 10640                            elev_cv  2015          worked
# 10641                  gross_stem_volume  2015          worked
# 10642                      loreys_height  2015          worked
# 10643  percentage_first_returns_above_2m  2015          worked
# 10644                      total_biomass  2015          worked
# 10645                                HMM  2015          worked
# 10646                        disturbance  2015          worked
# 10647                    disturbance_all  2015          worked
# 10651                         basal_area  2015          worked
# 10652                            elev_cv  2015          worked
# 10653                  gross_stem_volume  2015          worked
# 10654                      loreys_height  2015          worked
# 10655  percentage_first_returns_above_2m  2015          worked
# 10656                      total_biomass  2015          worked
# 10657                                HMM  2015          worked
# 10658                        disturbance  2015          worked
# 10659                    disturbance_all  2015          worked
# 10663                         basal_area  2015          worked
# 10664                            elev_cv  2015          worked
# 10665                  gross_stem_volume  2015          worked
# 10666                      loreys_height  2015          worked
# 10667  percentage_first_returns_above_2m  2015          worked
# 10668                      total_biomass  2015          worked
# 10669                                HMM  2015          worked
# 10670                        disturbance  2015          worked
# 10671                    disturbance_all  2015          worked
# 10675                         basal_area  2015          worked
# 10676                            elev_cv  2015          worked
# 10677                  gross_stem_volume  2015          worked
# 10678                      loreys_height  2015          worked
# 10679  percentage_first_returns_above_2m  2015          worked
# 10680                      total_biomass  2015          worked
# 10681                                HMM  2015          worked
# 10682                        disturbance  2015          worked
# 10683                    disturbance_all  2015          worked
# 10687                         basal_area  2015          worked
# 10688                            elev_cv  2015          worked
# 10689                  gross_stem_volume  2015          worked
# 10690                      loreys_height  2015          worked
# 10691  percentage_first_returns_above_2m  2015          worked
# 10692                      total_biomass  2015          worked
# 10693                                HMM  2015          worked
# 10694                        disturbance  2015          worked
# 10695                    disturbance_all  2015          worked
# 10699                         basal_area  2015          worked
# 10700                            elev_cv  2015          worked
# 10701                  gross_stem_volume  2015          worked
# 10702                      loreys_height  2015          worked
# 10703  percentage_first_returns_above_2m  2015          worked
# 10704                      total_biomass  2015          worked
# 10705                                HMM  2015          worked
# 10706                        disturbance  2015          worked
# 10707                    disturbance_all  2015          worked
# 10711                         basal_area  2015          worked
# 10712                            elev_cv  2015          worked
# 10713                  gross_stem_volume  2015          worked
# 10714                      loreys_height  2015          worked
# 10715  percentage_first_returns_above_2m  2015          worked
# 10716                      total_biomass  2015          worked
# 10717                                HMM  2015          worked
# 10718                        disturbance  2015          worked
# 10719                    disturbance_all  2015          worked
# 10723                         basal_area  2015          worked
# 10724                            elev_cv  2015          worked
# 10725                  gross_stem_volume  2015          worked
# 10726                      loreys_height  2015          worked
# 10727  percentage_first_returns_above_2m  2015          worked
# 10728                      total_biomass  2015          worked
# 10729                                HMM  2015          worked
# 10730                        disturbance  2015          worked
# 10731                    disturbance_all  2015          worked
# 10735                         basal_area  2015          worked
# 10736                            elev_cv  2015          worked
# 10737                  gross_stem_volume  2015          worked
# 10738                      loreys_height  2015          worked
# 10739  percentage_first_returns_above_2m  2015          worked
# 10740                      total_biomass  2015          worked
# 10741                                HMM  2015          worked
# 10742                        disturbance  2015          worked
# 10743                    disturbance_all  2015          worked
# 10747                         basal_area  2015          worked
# 10748                            elev_cv  2015          worked
# 10749                  gross_stem_volume  2015          worked
# 10750                      loreys_height  2015          worked
# 10751  percentage_first_returns_above_2m  2015          worked
# 10752                      total_biomass  2015          worked
# 10753                                HMM  2015          worked
# 10754                        disturbance  2015          worked
# 10755                    disturbance_all  2015          worked
# 10759                         basal_area  2015          worked
# 10760                            elev_cv  2015          worked
# 10761                  gross_stem_volume  2015          worked
# 10762                      loreys_height  2015          worked
# 10763  percentage_first_returns_above_2m  2015          worked
# 10764                      total_biomass  2015          worked
# 10765                                HMM  2015          worked
# 10766                        disturbance  2015          worked
# 10767                    disturbance_all  2015          worked
# 10771                         basal_area  2015          worked
# 10772                            elev_cv  2015          worked
# 10773                  gross_stem_volume  2015          worked
# 10774                      loreys_height  2015          worked
# 10775  percentage_first_returns_above_2m  2015          worked
# 10776                      total_biomass  2015          worked
# 10777                                HMM  2015          worked
# 10778                        disturbance  2015          worked
# 10779                    disturbance_all  2015          worked
# 10783                         basal_area  2015          worked
# 10784                            elev_cv  2015          worked
# 10785                  gross_stem_volume  2015          worked
# 10786                      loreys_height  2015          worked
# 10787  percentage_first_returns_above_2m  2015          worked
# 10788                      total_biomass  2015          worked
# 10789                                HMM  2015          worked
# 10790                        disturbance  2015          worked
# 10791                    disturbance_all  2015          worked
# 10795                         basal_area  2015          worked
# 10796                            elev_cv  2015          worked
# 10797                  gross_stem_volume  2015          worked
# 10798                      loreys_height  2015          worked
# 10799  percentage_first_returns_above_2m  2015          worked
# 10800                      total_biomass  2015          worked
# 10801                                HMM  2015          worked
# 10802                        disturbance  2015          worked
# 10803                    disturbance_all  2015          worked
# 10807                         basal_area  2015          worked
# 10808                            elev_cv  2015          worked
# 10809                  gross_stem_volume  2015          worked
# 10810                      loreys_height  2015          worked
# 10811  percentage_first_returns_above_2m  2015          worked
# 10812                      total_biomass  2015          worked
# 10813                                HMM  2015          worked
# 10814                        disturbance  2015          worked
# 10815                    disturbance_all  2015          worked
# 10819                         basal_area  2015          worked
# 10820                            elev_cv  2015          worked
# 10821                  gross_stem_volume  2015          worked
# 10822                      loreys_height  2015          worked
# 10823  percentage_first_returns_above_2m  2015          worked
# 10824                      total_biomass  2015          worked
# 10825                                HMM  2015          worked
# 10826                        disturbance  2015          worked
# 10827                    disturbance_all  2015          worked
# 10831                         basal_area  2015          worked
# 10832                            elev_cv  2015          worked
# 10833                  gross_stem_volume  2015          worked
# 10834                      loreys_height  2015          worked
# 10835  percentage_first_returns_above_2m  2015          worked
# 10836                      total_biomass  2015          worked
# 10837                                HMM  2015          worked
# 10838                        disturbance  2015          worked
# 10839                    disturbance_all  2015          worked
# 10843                         basal_area  2015          worked
# 10844                            elev_cv  2015          worked
# 10845                  gross_stem_volume  2015          worked
# 10846                      loreys_height  2015          worked
# 10847  percentage_first_returns_above_2m  2015          worked
# 10848                      total_biomass  2015          worked
# 10849                                HMM  2015          worked
# 10850                        disturbance  2015          worked
# 10851                    disturbance_all  2015          worked
# 10855                         basal_area  2015          worked
# 10856                            elev_cv  2015          worked
# 10857                  gross_stem_volume  2015          worked
# 10858                      loreys_height  2015          worked
# 10859  percentage_first_returns_above_2m  2015          worked
# 10860                      total_biomass  2015          worked
# 10861                                HMM  2015          worked
# 10862                        disturbance  2015          worked
# 10863                    disturbance_all  2015          worked
# 10867                         basal_area  2015          worked
# 10868                            elev_cv  2015          worked
# 10869                  gross_stem_volume  2015          worked
# 10870                      loreys_height  2015          worked
# 10871  percentage_first_returns_above_2m  2015          worked
# 10872                      total_biomass  2015          worked
# 10873                                HMM  2015          worked
# 10874                        disturbance  2015          worked
# 10875                    disturbance_all  2015          worked
# 10879                         basal_area  2015          worked
# 10880                            elev_cv  2015          worked
# 10881                  gross_stem_volume  2015          worked
# 10882                      loreys_height  2015          worked
# 10883  percentage_first_returns_above_2m  2015          worked
# 10884                      total_biomass  2015          worked
# 10885                                HMM  2015          worked
# 10886                        disturbance  2015          worked
# 10887                    disturbance_all  2015          worked
# 10891                         basal_area  2015          worked
# 10892                            elev_cv  2015          worked
# 10893                  gross_stem_volume  2015          worked
# 10894                      loreys_height  2015          worked
# 10895  percentage_first_returns_above_2m  2015          worked
# 10896                      total_biomass  2015          worked
# 10897                                HMM  2015          worked
# 10898                        disturbance  2015          worked
# 10899                    disturbance_all  2015          worked
# 10903                         basal_area  2015          worked
# 10904                            elev_cv  2015          worked
# 10905                  gross_stem_volume  2015          worked
# 10906                      loreys_height  2015          worked
# 10907  percentage_first_returns_above_2m  2015          worked
# 10908                      total_biomass  2015          worked
# 10909                                HMM  2015          worked
# 10910                        disturbance  2015          worked
# 10911                    disturbance_all  2015          worked
# 10915                         basal_area  2015          worked
# 10916                            elev_cv  2015          worked
# 10917                  gross_stem_volume  2015          worked
# 10918                      loreys_height  2015          worked
# 10919  percentage_first_returns_above_2m  2015          worked
# 10920                      total_biomass  2015          worked
# 10921                                HMM  2015          worked
# 10922                        disturbance  2015          worked
# 10923                    disturbance_all  2015          worked
# 10927                         basal_area  2015          worked
# 10928                            elev_cv  2015          worked
# 10929                  gross_stem_volume  2015          worked
# 10930                      loreys_height  2015          worked
# 10931  percentage_first_returns_above_2m  2015          worked
# 10932                      total_biomass  2015          worked
# 10933                                HMM  2015          worked
# 10934                        disturbance  2015          worked
# 10935                    disturbance_all  2015          worked
# 10939                         basal_area  2015          worked
# 10940                            elev_cv  2015          worked
# 10941                  gross_stem_volume  2015          worked
# 10942                      loreys_height  2015          worked
# 10943  percentage_first_returns_above_2m  2015          worked
# 10944                      total_biomass  2015          worked

# %% [markdown]
# # Variables are now clipped to the PACE, next need to aggregate average data to subzones: New notebook start point?

# %%
structVars = ["basal_area", "elev_cv", "gross_stem_volume",
             "loreys_height", "percentage_first_returns_above_2m", 
             "total_biomass"]
meanVars = structVars + ["elevation", "slope", "aspect", "insolation"]

meanVars = tuple([s + ".tif" for s in meanVars])

# %%
def zStatsMean(fName, subzone):
    metadata = fName.split("\\")[-1].split(".")[0].split("-")
    var = metadata[-1]
    if var in structVars:
        year = metadata[1]
    else:
        year = None
    tSaveLoc = os.path.join(scratch, fName.split("\\")[-1].split(".")[0] + ".dbf")
    zonalOut = ZonalStatisticsAsTable(subzone, "myFID", fName, tSaveLoc, "DATA", "MEAN")
    arcpy.JoinField_management(zonalOut, "myFID", subzone, "myFID", ["ppa_gpe", "ZONE", "SUBZONE", "VARIANT", "PHASE", "NATURAL_DI", "Shape_Area"])
    if var in structVars:
        arcpy.CalculateField_management(zonalOut, "year", year, field_type = "SHORT")
    arcpy.CalculateField_management(zonalOut, "var", "var", field_type = "TEXT")
    arcpy.CalculateField_management(zonalOut, "park", "parkName", field_type = "TEXT")
    csv_save = fName.split("\\")[-1].split(".")[0] + ".csv"
    zStats_csv = arcpy.TableToTable_conversion(zonalOut, scratch, csv_save)
    return os.path.join(scratch, csv_save)

# %%
num_done = 0

# %%
d = 'outputs'
parkFolders = [os.path.join(wd, d, o) for o in os.listdir(d) 
                    if os.path.isdir(os.path.join(d,o))]

outDbfs = []

for park in parkFolders[num_done:]:
    files_done = 0
    parkName = park.rsplit("\\", 1)[-1]
    #print(parkName)
    subzone = os.path.join(park, parkName + "_PACE_Subzones.shp")
    #print(subzone)
    rasterLoc = os.path.join(park, "rasters")
    #print(rasterLoc)
    if os.path.isdir(rasterLoc):
        num_rasters = (len([name for name in os.listdir(rasterLoc) if name.endswith(meanVars)]))

        for file in os.listdir(rasterLoc):
            #for meanVar in meanVars:
            if file.endswith(meanVars):
                clear_output(True)
                print(str(num_done), "/", str(len(parkFolders)), "parks")
                print(files_done, "/", num_rasters, "working on", file)
                
                fileLoc = os.path.join(rasterLoc, file)
                metadata = file.split(".")[0].split("-")
                var = metadata[-1]
                outDbfs.append(zStatsMean(fileLoc, subzone))
                files_done += 1
    num_done += 1

            
            
clear_output(True)
print("merging")

        #if file.endswith(propVars):
            #propLocs.append(os.path.join(rasterLoc, file))
combined_csv = pd.concat( [ pd.read_csv(f) for f in outDbfs ] )
combined_csv.to_csv(os.path.join("outputCsvs", "meanVars.csv"))

for file in os.listdir(scratch):
    os.remove(os.path.join(scratch, file))
print("done!")
# Out:
# 1 / 979 parks
# 2 / 9 working on AdamsLakeMarineParkRefugeBaySite_PACE-2015-gross_stem_volume.tif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-1ad220a52ea2> in <module>
#      26                 metadata = file.split(".")[0].split("-")
#      27                 var = metadata[-1]
# ---> 28                 outDbfs.append(zStatsMean(fileLoc, subzone))
#      29                 files_done += 1
#      30     num_done += 1
#
# <ipython-input-25-897de757ad00> in zStatsMean(fName, subzone)
#       7         year = None
#       8     tSaveLoc = os.path.join(scratch, fName.split("\\")[-1].split(".")[0] + ".dbf")
# ----> 9     zonalOut = ZonalStatisticsAsTable(subzone, "myFID", fName, tSaveLoc, "DATA", "MEAN")
#      10     arcpy.JoinField_management(zonalOut, "myFID", subzone, "myFID", ["ppa_gpe", "ZONE", "SUBZONE", "VARIANT", "PHASE", "NATURAL_DI", "Shape_Area"])
#      11     if var in structVars:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\sa\Functions.py in ZonalStatisticsAsTable(in_zone_data, zone_field, in_value_raster, out_table, ignore_nodata, statistics_type, process_as_multidimensional)
#    6585         ignore_nodata,
#    6586         statistics_type,
# -> 6587         process_as_multidimensional)
#    6588 ZonalStatisticsAsTable.__esri_toolname__ = "ZonalStatisticsAsTable_sa"
#    6589 ZonalStatisticsAsTable.__esri_toolinfo__ = [
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\sa\Utils.py in swapper(*args, **kwargs)
#      51
#      52             try:
# ---> 53                 result = wrapper(*args, **kwargs)
#      54             finally:
#      55                 # Reset the geoprocessor state to the original setting.
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\sa\Functions.py in Wrapper(in_zone_data, zone_field, in_value_raster, out_table, ignore_nodata, statistics_type, process_as_multidimensional)
#    6576             ignore_nodata,
#    6577             statistics_type,
# -> 6578             process_as_multidimensional)
#    6579         return result
#    6580     return Wrapper(
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     509         val = getattr(self._gp, attr)
#     510         if callable(val):
# --> 511             return lambda *args: val(*gp_fixargs(args, True))
#     512         else:
#     513             return convertArcObjectToPythonObject(val)
#
# KeyboardInterrupt:

# %%
folders = [os.path.join(folder.rsplit("\\")[0], folder.rsplit("\\")[1], "rasters") for folder in for_clipping]

# %%
folders
years = list(range(1985, 2019))

df = pd.DataFrame(it.product(folders, years, inVars), columns=['folder', 'year', "variable"])

# %%
df["park"] = df.folder.str.rsplit("\\").str.get(1)

# %%
disturbance_df = df[df.variable == "disturbance"]
other_df = df[df.year == 2015]
other_df = df[df.variable != "disturbance"]

# %%
all_files = pd.concat([disturbance_df, other_df])

# %%
all_files.to_csv("files_for_checking.csv")
